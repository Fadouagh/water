# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

# %%
tw_path = open("/Users/basho/fadouaproject/SafeWater/files/twData.csv","r")
tw_data = pd.read_csv(tw_path, header=0)

# %%
def data_desc(data):
    print("Columns names",data.columns)
    print("Size", data.shape)
    print("Basic statistics", data.describe())

data_desc(tw_data)
# Out:
# Columns names Index(['Timestamp', 'TwDate', 'TwLoc', 'TwUserName', 'TwUserID', 'TwID',
#        'TwContent', 'ContentLoc', 'urls', 'Unnamed: 9'],
#       dtype='object')
# Size (284, 10)
# Basic statistics            TwUserID          TwID
# count  2.840000e+02  2.840000e+02
# mean   2.760923e+17  1.039389e+18
# std    4.386059e+17  2.867855e+17
# min    8.057970e+05  0.000000e+00
# 25%    1.454432e+08  1.105132e+18
# 50%    5.346214e+08  1.122058e+18
# 75%    7.700654e+17  1.124268e+18
# max    1.123009e+18  1.141677e+18

# %%
tweets = tw_data.TwContent.values

# %% [markdown]
# ## 1. Normalization pipeline
# ### 1.1 Lower case

# %%
def lower_case(text):
    text_lower = text.lower()
    
    return text_lower

# %%
def lower_case_collection(array):
    array_lower = [lower_case(text) for text in array]
    
    return array_lower

# %% [markdown]
# ### 1.2  Remove punctuation

# %%
def remove_punctuation(text):
    obj = str.maketrans('', '',string.punctuation)
    text_unpunct = text.translate(obj)
    
    return text_unpunct

def remove_punctuation_collection(array):
    array_unpunct = [remove_punctuation(text) for text in array]
    
    return array_unpunct

# %%
#remove_punctuation_collection(tweets)

# %% [markdown]
# ### 1.3 Tokenization

# %%
def tokenize_word(text):
    words = word_tokenize(text)
    
    return words

def tokenize_word_collection(array):
    array_wtokens = [tokenize_word(text) for text in array]
    
    return array_wtokens

# %%
#tokenize_word_collection(tweets)

# %%
def tokenized_sent(text):
    sentences = sent_tokenize(text)
    
    return sentences

def tokenize_sent_collection(array):
    array_stokens = [tokenized_sent(text) for text in array]
    
    return array_stokens

# %%
#tokenize_sent_collection(tweets)

# %% [markdown]
# ### 1.4 appos
# No appos in French?

# %% [markdown]
# ### 1.5 stopwords

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words("french"))

# %%
def remove_stopwords(text):
    filtered_sentence = [] 
    word_tokens = word_tokenize(text)                                                
    filtered_sentence = [w for w in word_tokens if not w in stop_words]               
    text_nostopwords =' '.join(filtered_sentence) 
    
    return text_nostopwords

def remove_stopwords_collection(array):
    array_nostopwords = [remove_stopwords(text) for text in array]

    return array_nostopwords

# %%
#remove_stopwords_collection(tweets)

# %% [markdown]
# ### 1.6 Remove objects (urls, undesired symbols, etc.)

# %%
import re
url_pattern = r'(https?:\/\/)(\s)?(www\.)?(\s?)(\w+\.)*([\w\-\s]+\/)*([\w-]+)\/?'
space_pattern = u'\xa0'
#nonalphanumeric_pattern = r'[^a-zA-z0-9\s]'
nonalphanumeric_pattern = r'[^a-zA-z0-9àâäèéêëîïôœùûüÿçÀÂÄÈÉÊËÎÏÔŒÙÛÜŸÇ\s]'

# %%
def remove_pattern(text, pattern):
    text_clean = re.sub(pattern, '', text)
    
    return text_clean

def remove_pattern_collection(array, url_pattern):
    array_clean = [remove_pattern(text, url_pattern) for text in array]

    return array_clean

# %%
#remove_pattern_collection(tweets, url_pattern)
#remove_pattern_collection(tweets, space_pattern)
#remove_pattern_collection(tweets, nonalphanumeric_pattern)

# %% [markdown]
# ### 1.7 Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
import spacy

# %%
#!python -m spacy download fr_core_news_sm

# %%
#!python -m spacy download fr

# %%
sp = spacy.load('fr')

# %%
def lemmatize(sent):
    sentence = sp(sent)
    lemmas = []
    for word in sentence:  
        lemmas.append((word.text, word.lemma_))
    
    new_sentence = map(lambda x:sentence.replace(x[0],x[1]),sentence)
    return lemmas, new_sentence

def lemmatize_collection(array):
    array_stokens = tokenize_sent_collection(array)
    array_lemmas = []
    for para in array_stokens:
        for sent in para:
            array_lemmas.append(lemmatize(sent))
    
    return array_lemmas

# %%
lemmatize('La vie est courte')
# Out:
# ([('La', 'le'), ('vie', 'vie'), ('est', 'être'), ('courte', 'court')],
#  <map at 0x1a2a0d8320>)

# %%
lemmatize_collection(tweets)
# Out:
# [([('Les', 'le'),
#    ('gouvernorats', 'gouvernorat'),
#    ('de', 'de'),
#    ('Siliana', 'Siliana'),
#    (',', ','),
#    ('Kasserine', 'Kasserine'),
#    ('et', 'et'),
#    ('Jendouba', 'Jendouba'),
#    ('souffrent', 'souffrir'),
#    ('de', 'de'),
#    ('coupures', 'coupure'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/j0bbbzzVcp', 'https://t.co/j0bbbzzvcp')],
#   <map at 0x1a221c2390>),
#  ([('Perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupures', 'coupure'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('gouvernorats', 'gouvernorat'),
#    ('de', 'de'),
#    ('Siliana', 'Siliana'),
#    (',', ','),
#    ('Kasserine', 'Kasserine'),
#    ('et', 'et'),
#    ('Jendouba', 'jendouba'),
#    ('https://t.co/3Sk2V370g0', 'https://t.co/3Sk2V370g0')],
#   <map at 0x1a2d9d5da0>),
#  ([("L'", 'le'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('reprendra', 'reprendre'),
#    (',', ','),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('nuit', 'nuit'),
#    ('du', 'de'),
#    ('mardi', 'mardi'),
#    ('au', 'au'),
#    ('mercredi', 'mercredi'),
#    ('...', '...'),
#    ('https://t.co/hAFm4dmiCB', 'https://t.co/hafm4dmicb')],
#   <map at 0x1a2d9ea2e8>),
#  ([('Perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupures', 'coupure'),
#    ('dans', 'dans'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('quelques', 'quelque'),
#    ('régions', 'région'),
#    ('à', 'à'),
#    ('Jendouba', 'Jendouba'),
#    ('et', 'et'),
#    ('Béja', 'Béja'),
#    ('https://t.co/qnFhE9rRU0', 'https://t.co/qnFhE9rRU0')],
#   <map at 0x1a2d9ea6a0>),
#  ([('Perturbations', 'perturbation'),
#    ('dans', 'dans'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('quelques', 'quelque'),
#    ('régions', 'région'),
#    ('à', 'à'),
#    ('Jendouba', 'Jendouba'),
#    ('et', 'et'),
#    ('Béjà', 'Béjà'),
#    ('https://t.co/Hppav3y7sv', 'https://t.co/hppav3y7sv')],
#   <map at 0x1a2d9ea9e8>),
#  ([('La', 'le'),
#    ('reprise', 'reprise'),
#    ('sera', 'être'),
#    ('progressive', 'progressif'),
#    ('...', '...'),
#    ('https://t.co/6hRuGbJuy7', 'https://t.co/6hrugbjuy7'),
#    ('"', '"')],
#   <map at 0x1a2d9eac18>),
#  ([('#', '#'),
#    ('Tunisie', 'tunisie'),
#    (':', ':'),
#    ('Perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupures', 'coupure'),
#    ('dans', 'dans'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('à', 'à'),
#    ('Jendouba', 'Jendouba'),
#    ('et', 'et'),
#    ('à', 'à'),
#    ('Béja', 'Béja'),
#    ('https://t.co/34u2zoGUZ0', 'https://t.co/34u2zoguz0')],
#   <map at 0x1a2d9ee048>),
#  ([('Tunisie', 'tunisie'),
#    ('-', '-'),
#    ('Tozeur', 'tozeur'),
#    (':', ':'),
#    ('La', 'le'),
#    ('SONEDE', 'sonede'),
#    ('rassure', 'rassur'),
#    ('sur', 'sur'),
#    ('la', 'le'),
#    ('qualité', 'qualité'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/8kKk0aEvCI', 'https://t.co/8kkk0aevci')],
#   <map at 0x1a2d9ee550>),
#  ([('Nos', 'notre'),
#    ('gouvernants', 'gouvernant'),
#    ('ont', 'avoir'),
#    ("l'", 'le'),
#    ('habitude', 'habitude'),
#    ('de', 'de'),
#    ('prendre', 'prendre'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('minérale', 'minéral'),
#    ('pdt', 'pendant'),
#    ('que', 'que'),
#    ('les', 'le'),
#    ('populations', 'population'),
#    ('sont', 'être'),
#    ('en', 'en'),
#    ('quête', 'quête'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('.', '.')],
#   <map at 0x1a2d9eed30>),
#  ([('Les', 'le'),
#    ('habitants', 'habitant'),
#    ("d'", 'de'),
#    ('un', 'un'),
#    ('village', 'village'),
#    ('Kenyan', 'Kenyan'),
#    ('ont', 'avoir'),
#    ('servi', 'servir'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('sale', 'sale'),
#    ('aux', 'au'),
#    ('autorités', 'autoriter'),
#    ('lors', 'lors'),
#    ("d'", 'de'),
#    ('une', 'un'),
#    ('réunion', 'réunion'),
#    ('.', '.')],
#   <map at 0x1a2d9f3470>),
#  ([('Cela', 'celer'),
#    ('doit', 'devoir'),
#    ('servir', 'servir'),
#    ('de', 'de'),
#    ('leçon', 'leçon'),
#    ('à', 'à'),
#    ('tous', 'tout'),
#    ('.', '.')],
#   <map at 0x1a2d9f3748>),
#  ([('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    ('https://t.co/weB3WnXdWO', 'https://t.co/web3wnxdwo'),
#    ('https://t.co/agUbx3Upsw', 'https://t.co/agubx3upsw')],
#   <map at 0x1a2d9f3518>),
#  ([('Jendouba', 'jendouba'),
#    ('nord', 'nord'),
#    (':', ':'),
#    ('le', 'le'),
#    ('vol', 'vol'),
#    ('des', 'un'),
#    ('équipements', 'équipement'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('SONEDE', 'sonede'),
#    ('prive', 'prive'),
#    ('plusieurs', 'plusieurs'),
#    ('régions', 'région'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/CiiImo2QRI', 'https://t.co/ciiimo2qri')],
#   <map at 0x1a2d9f3dd8>),
#  ([('le', 'le'),
#    ('vol', 'vol'),
#    ('des', 'un'),
#    ('équipements', 'équipement'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('SONEDE', 'sonede'),
#    ('prive', 'prive'),
#    ('plusieurs', 'plusieurs'),
#    ('régions', 'région'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/K4PykDFykw', 'https://t.co/k4pykdfykw'),
#    ('https://t.co/dqXYeFItXt', 'https://t.co/dqXYeFItXt')],
#   <map at 0x1a2d9fa320>),
#  ([('Reprise', 'reprise'),
#    ('cette', 'ce'),
#    ('nuit', 'nuit'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('région', 'région'),
#    ('de', 'de'),
#    ('Radès', 'Radès'),
#    ('https://t.co/nAbyJ0Mqdz', 'https://t.co/nAbyJ0Mqdz')],
#   <map at 0x1a2d9fa828>),
#  ([('Selon', 'selon'),
#    ('un', 'un'),
#    ('communiqué', 'communiqué'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('SONEDE', 'SONEDE'),
#    ('...', '...'),
#    ('https://t.co/cgb39AfWeF', 'https://t.co/cgb39afwef')],
#   <map at 0x1a2d9fab70>),
#  ([('Malgré', 'malgré'),
#    ('le', 'le'),
#    ('retard', 'retard'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('réalisation', 'réalisation'),
#    ('...', '...'),
#    ('https://t.co/DJczsEnscn', 'https://t.co/djczsenscn')],
#   <map at 0x1a2d9fae48>),
#  ([('Ariana', 'ariana'),
#    (':', ':'),
#    ('pertrubation', 'pertrubation'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('plusieurs', 'plusieurs'),
#    ('région', 'région'),
#    ('demain', 'demain'),
#    ('à', 'à'),
#    ('partir', 'partir'),
#    ('de', 'de'),
#    ('21h', '21h'),
#    ('https://t.co/Pq0ZUtk7l1', 'https://t.co/pq0zutk7l1')],
#   <map at 0x1a2d9fc400>),
#  ([('pertrubation', 'pertrubation'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('plusieurs', 'plusieurs'),
#    ('région', 'région'),
#    ('demain', 'demain'),
#    ('à', 'à'),
#    ('partir', 'partir'),
#    ('de', 'de'),
#    ('\xa0', '  '),
#    ('21h', '21h'),
#    ('https://t.co/dzVjN9MQR4', 'https://t.co/dzVjN9MQR4'),
#    ('https://t.co/3uDgWNfKPk', 'https://t.co/3uDgWNfKPk')],
#   <map at 0x1a2d9fc8d0>),
#  ([('Tunisie', 'tunisie'),
#    (':', ':'),
#    ('Perturbation', 'perturbation'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('plusieurs', 'plusieurs'),
#    ('zones', 'zone'),
#    ('de', 'de'),
#    ('Raoued', 'Raoued'),
#    ('https://t.co/mW0QM8suaz', 'https://t.co/mw0qm8suaz')],
#   <map at 0x1a2d9fcdd8>),
#  ([('Une', 'un'),
#    ('perturbation', 'perturbation'),
#    ('et', 'et'),
#    ('une', 'un'),
#    ('coupure', 'coupure'),
#    ('dans', 'dans'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    (',', ','),
#    ('seront', 'être'),
#    ('enregistrées', 'enregistrer'),
#    ('à', 'à'),
#    ('partir', 'partir'),
#    ('du', 'de'),
#    ('mardi', 'mardi'),
#    ('19', '19'),
#    ('février', 'février'),
#    ('2019', '2019'),
#    (',', ','),
#    ('à', 'à'),
#    ('21H', '21H'),
#    (',', ','),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('délégation', 'délégation'),
#    ('de', 'de'),
#    ('#', '#'),
#    ('Raoued', 'Raoued'),
#    ('.', '.')],
#   <map at 0x1a2da016d8>),
#  ([('#', '#'),
#    ('Tunis', 'Tunis'),
#    ('#', '#'),
#    ('Actualité', 'actualité'),
#    ('https://t.co/gPZjeEFBwS', 'https://t.co/gpzjeefbw'),
#    ('https://t.co/KGuRRRc1l2', 'https://t.co/kgurrrc1l2')],
#   <map at 0x1a2da017f0>),
#  ([('A', 'a'),
#    ('partir', 'partir'),
#    ('de', 'de'),
#    ('demain', 'demain'),
#    (',', ','),
#    ('mardi', 'mardi'),
#    ('19', '19'),
#    ('février', 'février'),
#    ('2019', '2019'),
#    ('...', '...'),
#    ('https://t.co/XJC4x3GCFK', 'https://t.co/xjc4x3gcfk')],
#   <map at 0x1a2da01ba8>),
#  ([('Les', 'le'),
#    ('travaux', 'travail'),
#    ('se', 'se'),
#    ('poursuivent', 'poursuivre'),
#    ('pour', 'pour'),
#    ('assurer', 'assurer'),
#    ('la', 'le'),
#    ('reprise', 'reprise'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('#', '#'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('à', 'à'),
#    ('#', '#'),
#    ('Gafsa', 'Gafsa'),
#    ('(', '('),
#    ('SONEDE', 'sonede'),
#    (')', ')'),
#    ('https://t.co/GnvMp3DT3a', 'https://t.co/gnvmp3dt3a')],
#   <map at 0x1a2d917240>),
#  ([('Distribution', 'distribution'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    (':', ':'),
#    ('perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupure', 'coupure'),
#    ('à', 'à'),
#    ('Raoued', 'Raoued'),
#    ('ce', 'ce'),
#    ('soir', 'soir'),
#    ('https://t.co/7Yms5Qybde', 'https://t.co/7yms5qybd'),
#    ('https://t.co/VYidVPAQFI', 'https://t.co/vyidvpaqfi')],
#   <map at 0x1a2d9176d8>),
#  ([('Les', 'le'),
#    ('travaux', 'travail'),
#    ('se', 'se'),
#    ('poursuivent', 'poursuivre'),
#    ('pour', 'pour'),
#    ('assurer', 'assurer'),
#    ('la', 'le'),
#    ('reprise', 'reprise'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('#', '#'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('à', 'à'),
#    ('#', '#'),
#    ('Gafsa', 'Gafsa'),
#    ('(', '('),
#    ('SONEDE', 'sonede'),
#    (')', ')'),
#    ('https://t.co/GnvMp3DT3a', 'https://t.co/gnvmp3dt3a')],
#   <map at 0x1a2d917d30>),
#  ([('A', 'a'),
#    ('partir', 'partir'),
#    ('de', 'de'),
#    ('demain', 'demain'),
#    (',', ','),
#    ('mardi', 'mardi'),
#    ('19', '19'),
#    ('février', 'février'),
#    ('2019', '2019'),
#    ('...', '...'),
#    ('https://t.co/XJC4x3GCFK', 'https://t.co/xjc4x3gcfk')],
#   <map at 0x1a2d91e128>),
#  ([('Une', 'un'),
#    ('perturbation', 'perturbation'),
#    ('et', 'et'),
#    ('une', 'un'),
#    ('coupure', 'coupure'),
#    ('dans', 'dans'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    (',', ','),
#    ('seront', 'être'),
#    ('enregistrées', 'enregistrer'),
#    ('à', 'à'),
#    ('partir', 'partir'),
#    ('du', 'de'),
#    ('mardi', 'mardi'),
#    ('19', '19'),
#    ('février', 'février'),
#    ('2019', '2019'),
#    (',', ','),
#    ('à', 'à'),
#    ('21H', '21H'),
#    (',', ','),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('délégation', 'délégation'),
#    ('de', 'de'),
#    ('#', '#'),
#    ('Raoued', 'Raoued'),
#    ('.', '.')],
#   <map at 0x1a2d91e9e8>),
#  ([('#', '#'),
#    ('Tunis', 'Tunis'),
#    ('#', '#'),
#    ('Actualité', 'actualité'),
#    ('https://t.co/gPZjeEFBwS', 'https://t.co/gpzjeefbw'),
#    ('https://t.co/KGuRRRc1l2', 'https://t.co/kgurrrc1l2')],
#   <map at 0x1a2d91eb00>),
#  ([('Tunisie', 'tunisie'),
#    (':', ':'),
#    ('Perturbation', 'perturbation'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('plusieurs', 'plusieurs'),
#    ('zones', 'zone'),
#    ('de', 'de'),
#    ('Raoued', 'Raoued'),
#    ('https://t.co/mW0QM8suaz', 'https://t.co/mw0qm8suaz')],
#   <map at 0x1a2d920048>),
#  ([('pertrubation', 'pertrubation'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('plusieurs', 'plusieurs'),
#    ('région', 'région'),
#    ('demain', 'demain'),
#    ('à', 'à'),
#    ('partir', 'partir'),
#    ('de', 'de'),
#    ('\xa0', '  '),
#    ('21h', '21h'),
#    ('https://t.co/dzVjN9MQR4', 'https://t.co/dzVjN9MQR4'),
#    ('https://t.co/3uDgWNfKPk', 'https://t.co/3uDgWNfKPk')],
#   <map at 0x1a2d920518>),
#  ([('Ariana', 'ariana'),
#    (':', ':'),
#    ('pertrubation', 'pertrubation'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('plusieurs', 'plusieurs'),
#    ('région', 'région'),
#    ('demain', 'demain'),
#    ('à', 'à'),
#    ('partir', 'partir'),
#    ('de', 'de'),
#    ('21h', '21h'),
#    ('https://t.co/Pq0ZUtk7l1', 'https://t.co/pq0zutk7l1')],
#   <map at 0x1a2d920a90>),
#  ([('Malgré', 'malgré'),
#    ('le', 'le'),
#    ('retard', 'retard'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('réalisation', 'réalisation'),
#    ('...', '...'),
#    ('https://t.co/DJczsEnscn', 'https://t.co/djczsenscn')],
#   <map at 0x1a2d920d68>),
#  ([('Selon', 'selon'),
#    ('un', 'un'),
#    ('communiqué', 'communiqué'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('SONEDE', 'SONEDE'),
#    ('...', '...'),
#    ('https://t.co/cgb39AfWeF', 'https://t.co/cgb39afwef')],
#   <map at 0x1a2d9270f0>),
#  ([('Reprise', 'reprise'),
#    ('cette', 'ce'),
#    ('nuit', 'nuit'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('région', 'région'),
#    ('de', 'de'),
#    ('Radès', 'Radès'),
#    ('https://t.co/nAbyJ0Mqdz', 'https://t.co/nAbyJ0Mqdz')],
#   <map at 0x1a2d9275f8>),
#  ([('le', 'le'),
#    ('vol', 'vol'),
#    ('des', 'un'),
#    ('équipements', 'équipement'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('SONEDE', 'sonede'),
#    ('prive', 'prive'),
#    ('plusieurs', 'plusieurs'),
#    ('régions', 'région'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('\xa0', '  '),
#    ('potable', 'potable'),
#    ('https://t.co/K4PykDFykw', 'https://t.co/k4pykdfykw'),
#    ('https://t.co/dqXYeFItXt', 'https://t.co/dqXYeFItXt')],
#   <map at 0x1a2d927b38>),
#  ([('Jendouba', 'jendouba'),
#    ('nord', 'nord'),
#    (':', ':'),
#    ('le', 'le'),
#    ('vol', 'vol'),
#    ('des', 'un'),
#    ('équipements', 'équipement'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('SONEDE', 'sonede'),
#    ('prive', 'prive'),
#    ('plusieurs', 'plusieurs'),
#    ('régions', 'région'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/CiiImo2QRI', 'https://t.co/ciiimo2qri')],
#   <map at 0x1a2d92c160>),
#  ([('Nos', 'notre'),
#    ('gouvernants', 'gouvernant'),
#    ('ont', 'avoir'),
#    ("l'", 'le'),
#    ('habitude', 'habitude'),
#    ('de', 'de'),
#    ('prendre', 'prendre'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('minérale', 'minéral'),
#    ('pdt', 'pendant'),
#    ('que', 'que'),
#    ('les', 'le'),
#    ('populations', 'population'),
#    ('sont', 'être'),
#    ('en', 'en'),
#    ('quête', 'quête'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('.', '.')],
#   <map at 0x1a2d92c940>),
#  ([('Les', 'le'),
#    ('habitants', 'habitant'),
#    ("d'", 'de'),
#    ('un', 'un'),
#    ('village', 'village'),
#    ('Kenyan', 'Kenyan'),
#    ('ont', 'avoir'),
#    ('servi', 'servir'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('sale', 'sale'),
#    ('aux', 'au'),
#    ('autorités', 'autoriter'),
#    ('lors', 'lors'),
#    ("d'", 'de'),
#    ('une', 'un'),
#    ('réunion', 'réunion'),
#    ('.', '.')],
#   <map at 0x1a2d92f080>),
#  ([('Cela', 'celer'),
#    ('doit', 'devoir'),
#    ('servir', 'servir'),
#    ('de', 'de'),
#    ('leçon', 'leçon'),
#    ('à', 'à'),
#    ('tous', 'tout'),
#    ('.', '.')],
#   <map at 0x1a2d92f358>),
#  ([('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    ('https://t.co/weB3WnXdWO', 'https://t.co/web3wnxdwo'),
#    ('https://t.co/agUbx3Upsw', 'https://t.co/agubx3upsw')],
#   <map at 0x1a2d92f128>),
#  ([('A', 'a'),
#    ('Fondouk', 'Fondouk'),
#    ('Jedid', 'Jedid'),
#    (',', ','),
#    ('sit-in', 'sit-in'),
#    ('et', 'et'),
#    ('arrêt', 'arrêt'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('pompe', 'pompe'),
#    ('du', 'de'),
#    ('canal', 'canal'),
#    ('Majerda', 'Majerda'),
#    ('desservant', 'desservir'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/Oi2vBIMfqP', 'https://t.co/oi2vbimfqp')],
#   <map at 0x1a2d92fa58>),
#  ([('Il', 'il'),
#    ('s’', 's’'),
#    ('agit', 'agir'),
#    ('d’', 'd’'),
#    ('un', 'un'),
#    ('projet', 'projet'),
#    ('d’', 'd’'),
#    ('appui', 'appui'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('production', 'production'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('le', 'le'),
#    ('Grand', 'grand'),
#    ('-', '-'),
#    ('Tunis', 'Tunis'),
#    ('avec', 'avec'),
#    ('une', 'un'),
#    ('capacité', 'capacité'),
#    ('de', 'de'),
#    ('production', 'production'),
#    ('de', 'de'),
#    ('100', '100'),
#    ('mille', 'mill'),
#    ('m3', 'm3'),
#    ('par', 'par'),
#    ('jour', 'jour'),
#    ('.', '.')],
#   <map at 0x1a2d933550>),
#  ([('Le', 'le'),
#    ('2ème', '2èm'),
#    ('projet', 'projet'),
#    ('porte', 'porte'),
#    (',', ','),
#    ('en', 'en'),
#    ('outre', 'outre'),
#    (',', ','),
#    ('sur', 'sur'),
#    ('la', 'le'),
#    ('station', 'station'),
#    ('du', 'de'),
#    ('traitement', 'traitement'),
#    ('des', 'un'),
#    ('eaux', 'eau'),
#    ('usées', 'user'),
#    ('avec', 'avec'),
#    ('une', 'un'),
#    ('capacité', 'capacité'),
#    ('de', 'de'),
#    ('production', 'production'),
#    ('...', '...'),
#    ('https://t.co/gP44Ij6eF6', 'https://t.co/gp44ij6ef6')],
#   <map at 0x1a2d933cc0>),
#  ([('Le', 'le'),
#    ('Grand', 'grand'),
#    ('Tunis', 'Tunis'),
#    ('n’', 'n’'),
#    ('aura', 'avoir'),
#    ('plus', 'plus'),
#    ('de', 'de'),
#    ('soucis', 'souci'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/I14KyCL4u4', 'https://t.co/i14kycl4u4')],
#   <map at 0x1a2d937198>),
#  ([('Le', 'le'),
#    ('Chef', 'chef'),
#    ('du', 'de'),
#    ('gouvernement', 'gouvernement'),
#    ('Youssef', 'Youssef'),
#    ('Chahed', 'chahed'),
#    ('inaugure', 'inaugurer'),
#    ('deux', 'deux'),
#    ('importants', 'important'),
#    ('projets', 'projet'),
#    ('à', 'à'),
#    ('Ghedir', 'Ghedir'),
#    ('el', 'el'),
#    ('Golla', 'Golla'),
#    ('consacrés', 'consacrer'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/45kmZaWbr4', 'https://t.co/45kmzawbr4')],
#   <map at 0x1a2d937780>),
#  ([('Le', 'le'),
#    ('Chef', 'chef'),
#    ('du', 'de'),
#    ('gouvernement', 'gouvernement'),
#    ('inaugure', 'inaugur'),
#    ('deux', 'deux'),
#    ('importants', 'important'),
#    ('projets', 'projet'),
#    ('à', 'à'),
#    ('Ghedir', 'Ghedir'),
#    ('el', 'el'),
#    ('Golla', 'Golla'),
#    ('consacrés', 'consacrer'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('|', '|'),
#    ('Tunivisions', 'Tunivisions'),
#    ('https://t.co/GTxP6i5HEg', 'https://t.co/gtxp6i5heg'),
#    ('via', 'via'),
#    ('@Tunivisions', '@tunivision')],
#   <map at 0x1a2d937d30>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.'),
#    ('Il', 'il'),
#    ('faut', 'falloir'),
#    ('…', '…')],
#   <map at 0x1a2d942588>),
#  ([('Perturbation', 'perturbation'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('zone', 'zone'),
#    ('inférieure', 'inférieur'),
#    ('à', 'à'),
#    ('Utique', 'Utique'),
#    ('\xa0', '  '),
#    ('ville', 'ville'),
#    ('https://t.co/0wZ7AKliWu', 'https://t.co/0wZ7AKliWu'),
#    ('https://t.co/jbPB7AjhU8', 'https://t.co/jbpb7ajhu8')],
#   <map at 0x1a2d942ac8>),
#  ([('Utique', 'Utique'),
#    (':', ':'),
#    ('Perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupures', 'coupure'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('|', '|'),
#    ('RTCI', 'RTCI'),
#    ('-', '-'),
#    ('Radio', 'Radio'),
#    ('Tunis', 'Tunis'),
#    ('Chaîne', 'Chaîne'),
#    ('Internationale', 'Internationale'),
#    ('https://t.co/IM5dYzadB2', 'https://t.co/im5dyzadb2')],
#   <map at 0x1a2d945048>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d945780>),
#  ([('Il', 'il'), ('faut', 'falloir'), ('…', '…')], <map at 0x1a2d945908>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d94b080>),
#  ([('Il', 'il'), ('faut', 'falloir'), ('…', '…')], <map at 0x1a2d94b208>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d94b940>),
#  ([('Il', 'il'), ('faut', 'falloir'), ('…', '…')], <map at 0x1a2d94bac8>),
#  ([('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d9461d0>),
#  ([('Il', 'il'),
#    ('faut', 'falloir'),
#    ('trouver', 'trouver'),
#    ('une', 'un'),
#    ('alternative', 'alternative'),
#    ('à', 'à'),
#    ('la', 'le'),
#    ('#', '#'),
#    ('Sodeca', 'Sodeca'),
#    ('qui', 'qui'),
#    ('ne', 'ne'),
#    ('parvient', 'parvenir'),
#    ('pas', 'pas'),
#    ('à', 'à'),
#    ('satisfaire', 'satisfaire'),
#    ('le', 'le'),
#    ('besoin', 'besoin'),
#    ('de', 'de'),
#    ('ses', 'son'),
#    ('clients', 'client'),
#    ('.', '.')],
#   <map at 0x1a2d946898>),
#  ([('Ayez', 'Ayez'),
#    ('pitié', 'pitier'),
#    ('de', 'de'),
#    ('ses', 'son'),
#    ('mères', 'mère'),
#    ("d'", 'de'),
#    ('enfants', 'enfant'),
#    ('!', '!')],
#   <map at 0x1a2d946ba8>),
#  ([('@GouvCF', '@gouvcf'),
#    ('@RJDH_RCA', '@rjdh_rca'),
#    ('https://t.co/EUVe2AEYI1', 'https://t.co/euve2aeyi1')],
#   <map at 0x1a2d946c88>),
#  ([('Samir', 'samir'),
#    ('Taieb', 'Taieb'),
#    (':', ':'),
#    ('un', 'un'),
#    ('plan', 'plan'),
#    ('national', 'national'),
#    ('mis', 'mettre'),
#    ('en', 'en'),
#    ('place', 'place'),
#    ('pour', 'pour'),
#    ('sécuriser', 'sécuriser'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('durant', 'durer'),
#    ('l’', 'l’'),
#    ('été', 'été'),
#    ('2019', '2019'),
#    ('https://t.co/Ldm9kbixqp', 'https://t.co/ldm9kbixqp'),
#    ('https://t.co/cj3VX8iD1J', 'https://t.co/cj3vx8id1j')],
#   <map at 0x1a2d950358>),
#  ([('A', 'a'),
#    ('Fondouk', 'Fondouk'),
#    ('Jedid', 'Jedid'),
#    (',', ','),
#    ('sit-in', 'sit-in'),
#    ('et', 'et'),
#    ('arrêt', 'arrêt'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('pompe', 'pompe'),
#    ('du', 'de'),
#    ('canal', 'canal'),
#    ('Majerda', 'Majerda'),
#    ('desservant', 'desservir'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/Oi2vBIMfqP', 'https://t.co/oi2vbimfqp')],
#   <map at 0x1a2d9509b0>),
#  ([('Consommation', 'consommation'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('le', 'le'),
#    ('secteur', 'secteur'),
#    ('touristique', 'touristique'),
#    (':', ':'),
#    ('611', '611'),
#    ('Litres', 'litre'),
#    ('par', 'par'),
#    ('Jour', 'Jour'),
#    ('et', 'et'),
#    ('par', 'par'),
#    ('lit', 'lit'),
#    ('occupé', 'occuper'),
#    ('.', '.')],
#   <map at 0x1a2d9520f0>),
#  ([('Telle', 'telle'),
#    ('une', 'un'),
#    ('douche', 'douche'),
#    ('froide', 'froid'),
#    ('sachant', 'savoir'),
#    ('que', 'que'),
#    ('pour', 'pour'),
#    ('remplir', 'remplir'),
#    ('une', 'un'),
#    ('baignoire', 'baignoir'),
#    (',', ','),
#    ('il', 'il'),
#    ('faudrait', 'falloir'),
#    ('200', '200'),
#    ('litres', 'litre'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('au', 'au'),
#    ('plus', 'plus'),
#    ('.', '.')],
#   <map at 0x1a2d952860>),
#  ([('Source', 'source'),
#    (':', ':'),
#    ('https://t.co/sISUlc2URZ', 'https://t.co/sisulc2urz'),
#    ('.', '.')],
#   <map at 0x1a2d952978>),
#  ([('Détails', 'détail'),
#    (':', ':'),
#    ('https://t.co/dXFEQv2htF', 'https://t.co/dxfeqv2htf'),
#    ('https://t.co/ZrCtT4xlvW', 'https://t.co/zrctt4xlvw')],
#   <map at 0x1a2d9528d0>),
#  ([('A', 'a'),
#    ('Fondouk', 'Fondouk'),
#    ('Jedid', 'Jedid'),
#    (',', ','),
#    ('sit-in', 'sit-in'),
#    ('et', 'et'),
#    ('arrêt', 'arrêt'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('pompe', 'pompe'),
#    ('du', 'de'),
#    ('canal', 'canal'),
#    ('Majerda', 'Majerda'),
#    ('desservant', 'desservir'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/Oi2vBIMfqP', 'https://t.co/oi2vbimfqp')],
#   <map at 0x1a2d96e0b8>),
#  ([('Il', 'il'),
#    ('s’', 's’'),
#    ('agit', 'agir'),
#    ('d’', 'd’'),
#    ('un', 'un'),
#    ('projet', 'projet'),
#    ('d’', 'd’'),
#    ('appui', 'appui'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('production', 'production'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('le', 'le'),
#    ('Grand', 'grand'),
#    ('-', '-'),
#    ('Tunis', 'Tunis'),
#    ('avec', 'avec'),
#    ('une', 'un'),
#    ('capacité', 'capacité'),
#    ('de', 'de'),
#    ('production', 'production'),
#    ('de', 'de'),
#    ('100', '100'),
#    ('mille', 'mill'),
#    ('m3', 'm3'),
#    ('par', 'par'),
#    ('jour', 'jour'),
#    ('.', '.')],
#   <map at 0x1a2d96eb70>),
#  ([('Le', 'le'),
#    ('2ème', '2èm'),
#    ('projet', 'projet'),
#    ('porte', 'porte'),
#    (',', ','),
#    ('en', 'en'),
#    ('outre', 'outre'),
#    (',', ','),
#    ('sur', 'sur'),
#    ('la', 'le'),
#    ('station', 'station'),
#    ('du', 'de'),
#    ('traitement', 'traitement'),
#    ('des', 'un'),
#    ('eaux', 'eau'),
#    ('usées', 'user'),
#    ('avec', 'avec'),
#    ('une', 'un'),
#    ('capacité', 'capacité'),
#    ('de', 'de'),
#    ('production', 'production'),
#    ('...', '...'),
#    ('https://t.co/gP44Ij6eF6', 'https://t.co/gp44ij6ef6')],
#   <map at 0x1a2d971320>),
#  ([('Le', 'le'),
#    ('Grand', 'grand'),
#    ('Tunis', 'Tunis'),
#    ('n’', 'n’'),
#    ('aura', 'avoir'),
#    ('plus', 'plus'),
#    ('de', 'de'),
#    ('soucis', 'souci'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/I14KyCL4u4', 'https://t.co/i14kycl4u4')],
#   <map at 0x1a2d9717b8>),
#  ([('Le', 'le'),
#    ('Chef', 'chef'),
#    ('du', 'de'),
#    ('gouvernement', 'gouvernement'),
#    ('Youssef', 'Youssef'),
#    ('Chahed', 'chahed'),
#    ('inaugure', 'inaugurer'),
#    ('deux', 'deux'),
#    ('importants', 'important'),
#    ('projets', 'projet'),
#    ('à', 'à'),
#    ('Ghedir', 'Ghedir'),
#    ('el', 'el'),
#    ('Golla', 'Golla'),
#    ('consacrés', 'consacrer'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/45kmZaWbr4', 'https://t.co/45kmzawbr4')],
#   <map at 0x1a2d971da0>),
#  ([('Le', 'le'),
#    ('Chef', 'chef'),
#    ('du', 'de'),
#    ('gouvernement', 'gouvernement'),
#    ('inaugure', 'inaugur'),
#    ('deux', 'deux'),
#    ('importants', 'important'),
#    ('projets', 'projet'),
#    ('à', 'à'),
#    ('Ghedir', 'Ghedir'),
#    ('el', 'el'),
#    ('Golla', 'Golla'),
#    ('consacrés', 'consacrer'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('|', '|'),
#    ('Tunivisions', 'Tunivisions'),
#    ('https://t.co/GTxP6i5HEg', 'https://t.co/gtxp6i5heg'),
#    ('via', 'via'),
#    ('@Tunivisions', '@tunivision')],
#   <map at 0x1a2d96f390>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d96fac8>),
#  ([('Il', 'il'), ('faut', 'falloir'), ('…', '…')], <map at 0x1a2d96fc50>),
#  ([('Perturbation', 'perturbation'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('zone', 'zone'),
#    ('inférieure', 'inférieur'),
#    ('à', 'à'),
#    ('Utique', 'Utique'),
#    ('\xa0', '  '),
#    ('ville', 'ville'),
#    ('https://t.co/0wZ7AKliWu', 'https://t.co/0wZ7AKliWu'),
#    ('https://t.co/jbPB7AjhU8', 'https://t.co/jbpb7ajhu8')],
#   <map at 0x1a2d97a1d0>),
#  ([('Utique', 'Utique'),
#    (':', ':'),
#    ('Perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupures', 'coupure'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('|', '|'),
#    ('RTCI', 'RTCI'),
#    ('-', '-'),
#    ('Radio', 'Radio'),
#    ('Tunis', 'Tunis'),
#    ('Chaîne', 'Chaîne'),
#    ('Internationale', 'Internationale'),
#    ('https://t.co/IM5dYzadB2', 'https://t.co/im5dyzadb2')],
#   <map at 0x1a2d97a710>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d97ae48>),
#  ([('Il', 'il'), ('faut', 'falloir'), ('…', '…')], <map at 0x1a2d97afd0>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d97f748>),
#  ([('Il', 'il'), ('faut', 'falloir'), ('…', '…')], <map at 0x1a2d97f8d0>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d980048>),
#  ([('Il', 'il'), ('faut', 'falloir'), ('…', '…')], <map at 0x1a2d9801d0>),
#  ([('#', '#'),
#    ('Centrafrique', 'Centrafrique'),
#    (':', ':'),
#    ('le', 'le'),
#    ('manque', 'manque'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('périphéries', 'périphérie'),
#    ('de', 'de'),
#    ('Bangui', 'Bangui'),
#    ('devient', 'devenir'),
#    ('un', 'un'),
#    ('problème', 'problème'),
#    ('plus', 'plus'),
#    ('épineux', 'épineux'),
#    ('que', 'que'),
#    ('jamais', 'jamais'),
#    ('.', '.')],
#   <map at 0x1a2d980898>),
#  ([('Il', 'il'),
#    ('faut', 'falloir'),
#    ('trouver', 'trouver'),
#    ('une', 'un'),
#    ('alternative', 'alternative'),
#    ('à', 'à'),
#    ('la', 'le'),
#    ('#', '#'),
#    ('Sodeca', 'Sodeca'),
#    ('qui', 'qui'),
#    ('ne', 'ne'),
#    ('parvient', 'parvenir'),
#    ('pas', 'pas'),
#    ('à', 'à'),
#    ('satisfaire', 'satisfaire'),
#    ('le', 'le'),
#    ('besoin', 'besoin'),
#    ('de', 'de'),
#    ('ses', 'son'),
#    ('clients', 'client'),
#    ('.', '.')],
#   <map at 0x1a2d980f60>),
#  ([('Ayez', 'Ayez'),
#    ('pitié', 'pitier'),
#    ('de', 'de'),
#    ('ses', 'son'),
#    ('mères', 'mère'),
#    ("d'", 'de'),
#    ('enfants', 'enfant'),
#    ('!', '!')],
#   <map at 0x1a2d9822b0>),
#  ([('@GouvCF', '@gouvcf'),
#    ('@RJDH_RCA', '@rjdh_rca'),
#    ('https://t.co/EUVe2AEYI1', 'https://t.co/euve2aeyi1')],
#   <map at 0x1a2d9823c8>),
#  ([('Samir', 'samir'),
#    ('Taieb', 'Taieb'),
#    (':', ':'),
#    ('un', 'un'),
#    ('plan', 'plan'),
#    ('national', 'national'),
#    ('mis', 'mettre'),
#    ('en', 'en'),
#    ('place', 'place'),
#    ('pour', 'pour'),
#    ('sécuriser', 'sécuriser'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('durant', 'durer'),
#    ('l’', 'l’'),
#    ('été', 'été'),
#    ('2019', '2019'),
#    ('https://t.co/Ldm9kbixqp', 'https://t.co/ldm9kbixqp'),
#    ('https://t.co/cj3VX8iD1J', 'https://t.co/cj3vx8id1j')],
#   <map at 0x1a2d982a20>),
#  ([('RT', 'rt'),
#    ('@WATCHWATER_TN', '@watchwater_tn'),
#    (':', ':'),
#    ('Moyenne', 'moyenne'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('Consommation', 'consommation'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('le', 'le'),
#    ('secteur', 'secteur'),
#    ('touristique', 'touristique'),
#    (':', ':'),
#    ('611', '611'),
#    ('Litres', 'litre'),
#    ('par', 'par'),
#    ('Jour', 'Jour'),
#    ('et', 'et'),
#    ('par', 'par'),
#    ('lit', 'lit'),
#    ('/', 'sur'),
#    ('personne', 'personne'),
#    ('.', '.')],
#   <map at 0x1a2d988320>),
#  ([('Un', 'un'), ('…', '…')], <map at 0x1a2d988438>),
#  ([('Moyenne', 'moyenne'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('Consommation', 'consommation'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('le', 'le'),
#    ('secteur', 'secteur'),
#    ('touristique', 'touristique'),
#    (':', ':'),
#    ('611', '611'),
#    ('Litres', 'litre'),
#    ('par', 'par'),
#    ('Jour', 'Jour'),
#    ('et', 'et'),
#    ('par', 'par'),
#    ('lit', 'lit'),
#    ('/', 'sur'),
#    ('personne', 'personne'),
#    ('.', '.')],
#   <map at 0x1a2d988c88>),
#  ([('Un', 'un'),
#    ('chiffre', 'chiffre'),
#    ('qui', 'qui'),
#    ('donne', 'donne'),
#    ('froid', 'froid'),
#    ('au', 'au'),
#    ('dos', 'do'),
#    ('sachant', 'savoir'),
#    ('que', 'que'),
#    ('pour', 'pour'),
#    ('remplir', 'remplir'),
#    ('une', 'un'),
#    ('baignoire', 'baignoir'),
#    (',', ','),
#    ('il', 'il'),
#    ('faudrait', 'falloir'),
#    ('200', '200'),
#    ('...', '...'),
#    ('https://t.co/kJvElUHf5I', 'https://t.co/kjveluhf5i')],
#   <map at 0x1a2d98d438>),
#  ([('@ikrmch', '@ikrmch'),
#    ('_', '_'),
#    ('C’', 'c’'),
#    ('est', 'être'),
#    ('le', 'le'),
#    ('pire', 'pire'),
#    ('peuple', 'peuple'),
#    ('.', '.')],
#   <map at 0x1a2d98d6d8>),
#  ([('Imagine', 'imagine'),
#    ('t’', 't’'),
#    ('es', 'e'),
#    ('milliardaire', 'milliardaire'),
#    (',', ','),
#    ('tu', 'tu'),
#    ('peux', 'pouvoir'),
#    ('développer', 'développer'),
#    ('l’', 'l’'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('plein', 'plein'),
#    ('de', 'de'),
#    ('pays', 'pays'),
#    (',', ','),
#    ('mais', 'mais'),
#    ('tu', 'tu'),
#    ('préfères', 'préfère'),
#    ('payer', 'payer'),
#    ('une', 'un'),
#    ('babtou', 'babtou'),
#    ('pour', 'pour'),
#    ('qu’', 'qu’'),
#    ('elle', 'lui'),
#    ('t’', 't’'),
#    ('enfonce', 'enfoncer'),
#    ('un', 'un'),
#    ('poisson', 'poisson'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('fesses', 'fesse')],
#   <map at 0x1a2d991160>),
#  ([('اضطراب', 'اضطراب'),
#    ('وانقطاع', 'وانقطاع'),
#    ('في', 'في'),
#    ('توزيع', 'توزيع'),
#    ('ماء', 'ماء'),
#    ('الشرب', 'الشرب'),
#    ('في', 'في'),
#    ('هذه', 'هذه'),
#    ('المناطق', 'المناطق'),
#    ('https://t.co/lof2ssHZpf', 'https://t.co/lof2sshzpf')],
#   <map at 0x1a2d991198>),
#  ([('Un', 'un'),
#    ('montant', 'montant'),
#    ('total', 'total'),
#    ('de', 'de'),
#    ('près', 'près'),
#    ('de', 'de'),
#    ('10,8', '10,8'),
#    ('millions', 'million'),
#    ('de', 'de'),
#    ('dollars', 'dollar'),
#    ('américains', 'américain'),
#    ('a', 'avoir'),
#    ('été', 'être'),
#    ('alloué', 'allouer'),
#    ('pour', 'pour'),
#    ('des', 'un'),
#    ('routes', 'route'),
#    ('extérieures', 'extérieur'),
#    ('et', 'et'),
#    ('des', 'un'),
#    ('raccordements', 'raccordement'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    (',', ','),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('électricité', 'électricité'),
#    ('et', 'et'),
#    ('au', 'au'),
#    ('gaz', 'gaz'),
#    (',', ','),
#    ('en', 'en'),
#    ('plus', 'plus'),
#    ('d’', 'd’'),
#    ('une', 'un'),
#    ('usine', 'usine'),
#    ('de', 'de'),
#    ('traitement', 'traitement'),
#    ('des', 'un'),
#    ('eaux', 'eau'),
#    ('usées', 'user'),
#    ('.', '.')],
#   <map at 0x1a2d991e80>),
#  ([('#', '#'),
#    ('Tunisie', 'tunisie'),
#    ('#', '#'),
#    ('Projet', 'Projet'),
#    ('#', '#'),
#    ('Investissement', 'investissement'),
#    ('https://t.co/q8Byvas98R', 'https://t.co/q8byvas98r')],
#   <map at 0x1a2d997048>),
#  ([('"', '"'),
#    ('A', 'a'),
#    ('l’', 'l’'),
#    ('échelle', 'échelle'),
#    ('national', 'national'),
#    (',', ','),
#    ('le', 'le'),
#    ('taux', 'taux'),
#    ('de', 'de'),
#    ('desserte', 'desserte'),
#    ('en', 'en'),
#    ('#', '#'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('est', 'être'),
#    ('en', 'en'),
#    ('constante', 'constant'),
#    ('augmentation', 'augmentation'),
#    ('depuis', 'depuis'),
#    ('20', '20'),
#    ('ans', 'an'),
#    ('.', '.')],
#   <map at 0x1a2d997588>),
#  ([('Mais', 'mais'),
#    ('aujourd’hui', 'aujourd’hui'),
#    (',', ','),
#    ('selon', 'selon'),
#    ('les', 'le'),
#    ('chiffres', 'chiffre'),
#    ('...', '...'),
#    ('https://t.co/lNyLQLyycn', 'https://t.co/lnylqlyycn')],
#   <map at 0x1a2d997828>),
#  ([('"', '"'),
#    ('A', 'a'),
#    ('l’', 'l’'),
#    ('échelle', 'échelle'),
#    ('nationale', 'national'),
#    (',', ','),
#    ('le', 'le'),
#    ('taux', 'taux'),
#    ('de', 'de'),
#    ('desserte', 'desserte'),
#    ('en', 'en'),
#    ('#', '#'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('est', 'être'),
#    ('en', 'en'),
#    ('constante', 'constant'),
#    ('augmentation', 'augmentation'),
#    ('depuis', 'depuis'),
#    ('20', '20'),
#    ('ans', 'an'),
#    ('.', '.')],
#   <map at 0x1a2d997d68>),
#  ([('Mais', 'mais'),
#    ('aujourd’hui', 'aujourd’hui'),
#    (',', ','),
#    ('selon', 'selon'),
#    ('les', 'le'),
#    ('chiffres', 'chiffre'),
#    ('...', '...'),
#    ('https://t.co/kODbQAwGFJ', 'https://t.co/kodbqawgfj')],
#   <map at 0x1a2d99e048>),
#  ([('RT', 'rt'),
#    ('@odilon236', '@odilon236'),
#    (':', ':'),
#    ('#', '#'),
#    ('CotedIvoire', 'cotedivoir'),
#    ('Traitement', 'traitement'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    (':', ':'),
#    ('Bientôt', 'Bientôt'),
#    ('une', 'un'),
#    ('usine', 'usine'),
#    ('de', 'de'),
#    ('108', '108'),
#    ('milliards', 'milliard'),
#    ('de', 'de'),
#    ('FCFA', 'fcfa'),
#    ('à', 'à'),
#    ('Abidjan', 'Abidjan'),
#    ('https://t.co/8BNJKOC8vz', 'https://t.co/8BNJKOC8vz'),
#    ('@abidja', '@abidja'),
#    ('…', '…')],
#   <map at 0x1a2d99e5c0>),
#  ([('#', '#'),
#    ('CotedIvoire', 'cotedivoir'),
#    ('Traitement', 'traitement'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    (':', ':'),
#    ('Bientôt', 'Bientôt'),
#    ('une', 'un'),
#    ('usine', 'usine'),
#    ('de', 'de'),
#    ('108', '108'),
#    ('milliards', 'milliard'),
#    ('de', 'de'),
#    ('FCFA', 'fcfa'),
#    ('à', 'à'),
#    ('Abidjan', 'Abidjan'),
#    ('https://t.co/8BNJKOC8vz', 'https://t.co/8BNJKOC8vz'),
#    ('@abidjantimes', '@abidjantimes'),
#    ('#', '#'),
#    ('Centrafrique', 'Centrafrique')],
#   <map at 0x1a2d99ea58>),
#  ([('Près', 'près'),
#    ('de', 'de'),
#    ('300.000', '300.000'),
#    ('personnes', 'personne'),
#    ('à', 'à'),
#    ('travers', 'travers'),
#    ('la', 'le'),
#    ('Tunisie', 'Tunisie'),
#    ('vivent', 'vivre'),
#    ('sans', 'sans'),
#    ('aucun', 'aucun'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('.', '.')],
#   <map at 0x1a2d99efd0>),
#  ([('Elles', 'lui'),
#    ('sont', 'être'),
#    ('obligées', 'obliger'),
#    ('de', 'de'),
#    ('recueillir', 'recueillir'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('de', 'de'),
#    ('pluie', 'pluie'),
#    ('ou', 'ou'),
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('sources', 'source'),
#    ('.', '.')],
#   <map at 0x1a2d9a45f8>),
#  ([('Analyse', 'analyse'),
#    ('en', 'en'),
#    ('chiffres', 'chiffre'),
#    ("d'", 'de'),
#    ('un', 'un'),
#    ('accès', 'accès'),
#    ('inégal', 'inégal'),
#    ('à', 'à'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('.', '.')],
#   <map at 0x1a2d9a4978>),
#  ([('https://t.co/tLSGPAtoFJ', 'https://t.co/tlsgpatofj'),
#    ('https://t.co/JLNPWA28nb', 'https://t.co/jlnpwa28nb')],
#   <map at 0x1a2d9a49b0>),
#  ([('RT', 'rt'),
#    ('@TUNumerique', '@tunumeriqu'),
#    (':', ':'),
#    ('Tunisie', 'tunisie'),
#    ('–', '–'),
#    ('La', 'le'),
#    ('SONEDE', 'sonede'),
#    ('annonce', 'annoncer'),
#    ('une', 'un'),
#    ('méga', 'méga-octet'),
#    ('coupure', 'coupure'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('sur', 'sur'),
#    ('le', 'le'),
#    ('grand', 'grand'),
#    ('Tunis', 'Tunis'),
#    ('https://t.co/h4l9pclVgQ', 'https://t.co/h4l9pclVgQ')],
#   <map at 0x1a2d9a7080>),
#  ([('La', 'le'),
#    ('SONEDE', 'sonede'),
#    ('annonce', 'annoncer'),
#    ('des', 'un'),
#    ('coupures', 'coupure'),
#    ('et', 'et'),
#    ('des', 'un'),
#    ('perturbations', 'perturbation'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    (' ', ' '),
#    ('dans', 'dans'),
#    ('diverses', 'divers'),
#    ('régions', 'région'),
#    ('de', 'de'),
#    ('Tunis', 'Tunis'),
#    ('et', 'et'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('Ariana', 'Ariana'),
#    ('–', '–'),
#    ('Prenez', 'prenez'),
#    ('donc', 'donc'),
#    ('vos', 'votre'),
#    ('précautions', 'précaution'),
#    ('dès', 'dès'),
#    ('ce', 'ce'),
#    ('soir', 'soir'),
#    ('https://t.co/ga3o4JNPiv', 'https://t.co/ga3o4jnpiv')],
#   <map at 0x1a2d9a7b00>),
#  ([('La', 'le'),
#    ('SONEDE', 'sonede'),
#    ('annonce', 'annoncer'),
#    ('des', 'un'),
#    ('coupures', 'coupure'),
#    ('et', 'et'),
#    ('des', 'un'),
#    ('perturbations', 'perturbation'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('diverses', 'divers'),
#    ('régions', 'région'),
#    ('de', 'de'),
#    ('Tunis', 'Tunis'),
#    ('et', 'et'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('Ariana', 'Ariana'),
#    ('|', '|'),
#    ('Tunivisions', 'Tunivisions'),
#    ('https://t.co/sibjEIU5kD', 'https://t.co/sibjeiu5kd'),
#    ('via', 'via'),
#    ('@Tunivisions', '@tunivision')],
#   <map at 0x1a2da78400>),
#  ([('Tunisie', 'tunisie'),
#    ('–', '–'),
#    ('La', 'le'),
#    ('SONEDE', 'sonede'),
#    ('annonce', 'annoncer'),
#    ('une', 'un'),
#    ('méga', 'méga-octet'),
#    ('coupure', 'coupure'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('sur', 'sur'),
#    ('le', 'le'),
#    ('grand', 'grand'),
#    ('Tunis', 'Tunis'),
#    ('https://t.co/h4l9pclVgQ', 'https://t.co/h4l9pclVgQ')],
#   <map at 0x1a2da789b0>),
#  ([('Tunis', 'Tunis'),
#    ('et', 'et'),
#    ('Ariana', 'Ariana'),
#    (':', ':'),
#    ('perturbations', 'perturbation'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/CgVQSddmXk', 'https://t.co/cgvqsddmxk')],
#   <map at 0x1a2da78dd8>),
#  ([('Perturbation', 'perturbation'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('à', 'à'),
#    ('Tunis', 'Tunis'),
#    ('et', 'et'),
#    ('à', 'à'),
#    ("l'", 'le'),
#    ('Ariana', 'Ariana'),
#    ('https://t.co/aOwPF599z4', 'https://t.co/aowpf599z4')],
#   <map at 0x1a2da7b2b0>),
#  ([('Reprise', 'reprise'),
#    ('progressive', 'progressif'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('le', 'le'),
#    ('grand', 'grand'),
#    ('Tunis', 'Tunis'),
#    ('https://t.co/tSUvv3KJ3A', 'https://t.co/tsuvv3kj3er'),
#    ('#', '#'),
#    ('Tunisie', 'tunisie')],
#   <map at 0x1a2da7b828>),
#  ([('Après', 'après'),
#    ('31', '31'),
#    ('heures', 'heure'),
#    ('de', 'de'),
#    ('travail', 'travail'),
#    ('continu', 'continu'),
#    ('...', '...'),
#    ('https://t.co/DNYR94MOKI', 'https://t.co/dnyr94moki')],
#   <map at 0x1a2da7bb70>),
#  ([('La', 'le'),
#    ('Société', 'Société'),
#    ('Nationale', 'national'),
#    ("d'", 'de'),
#    ('Exploitation', 'exploitation'),
#    ('et', 'et'),
#    ('de', 'de'),
#    ('Distribution', 'distribution'),
#    ('des', 'un'),
#    ('Eaux', 'eau'),
#    ('(', '('),
#    ('SONEDE', 'sonede'),
#    (')', ')'),
#    ('annonce', 'annoncer'),
#    ('la', 'le'),
#    ('fin', 'fin'),
#    ('des', 'un'),
#    ('travaux', 'travail'),
#    ('de', 'de'),
#    ('réparation', 'réparation'),
#    ('du', 'de'),
#    ('Canal', 'canal'),
#    ('principal', 'principal'),
#    ('de', 'de'),
#    ('distribution', 'distribution'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('pour', 'pour'),
#    ('Tunis', 'Tunis'),
#    ('et', 'et'),
#    ('l’', 'l’'),
#    ('Ariana', 'Ariana'),
#    ('https://t.co/Wplv4N4Huf', 'https://t.co/Wplv4N4Huf')],
#   <map at 0x1a2da82630>),
#  ([('La', 'le'),
#    ('SONEDE', 'sonede'),
#    ('annonce', 'annoncer'),
#    ('la', 'le'),
#    ('fin', 'fin'),
#    ('des', 'un'),
#    ('travaux', 'travail'),
#    ('de', 'de'),
#    ('réparation', 'réparation'),
#    ('du', 'de'),
#    ('Canal', 'canal'),
#    ('principal', 'principal'),
#    ('de', 'de'),
#    ('distribution', 'distribution'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('pour', 'pour'),
#    ('Tunis', 'Tunis'),
# ...
#    ('dans', 'dans'),
#    ('les', 'le'),
#    ('gouvernorats', 'gouvernorat'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('#', '#'),
#    ('Manouba', 'Manouba'),
#    ('et', 'et'),
#    ('#', '#'),
#    ('Béja', 'Béja'),
#    (':', ':'),
#    ('https://t.co/W0dUPP3AGH', 'https://t.co/w0dupp3agh'),
#    ('via', 'via'),
#    ('@espacemanager', '@espacemanager')],
#   <map at 0x1a2b461358>),
#  ([('Pour', 'pour'),
#    ('rapporter', 'rapporter'),
#    ('de', 'de'),
#    ("l'#eau", "l'#eau"),
#    ('potable', 'potable'),
#    ('à', 'à'),
#    ('leur', 'son'),
#    ('famille', 'famille'),
#    (',', ','),
#    ('ces', 'ce'),
#    ('femmes', 'femme'),
#    ('indiennes', 'indien'),
#    ('risquent', 'risquer'),
#    ('leur', 'son'),
#    ('vie', 'vie'),
#    ('chaque', 'chaque'),
#    ('jour', 'jour'),
#    ('en', 'en'),
#    ('descendant', 'descendre'),
#    ('en', 'en'),
#    ('rappel', 'rappel'),
#    ('dans', 'dans'),
#    ('un', 'un'),
#    ('puits', 'puits'),
#    ('de', 'de'),
#    ('18', '18'),
#    ('mètres', 'mètre'),
#    ('de', 'de'),
#    ('profondeur', 'profondeur'),
#    ('.', '.')],
#   <map at 0x1a2b461da0>),
#  ([('En', 'en'),
#    ('#', '#'),
#    ('Inde', 'Inde'),
#    (',', ','),
#    ('75', '75'),
#    ('%', 'pourcent'),
#    ('des', 'un'),
#    ('foyers', 'foyer'),
#    ("n'", 'ne'),
#    ('ont', 'avoir'),
#    ('pas', 'pas'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('.', '.')],
#   <map at 0x1a2b468358>),
#  ([('https://t.co/vDebFB6Bdz', 'https://t.co/vdebfb6bdz'),
#    ('#', '#'),
#    ('India', 'India'),
#    ('#', '#'),
#    ('HumanRight', 'HumanRight'),
#    ('to', 'to'),
#    ('#', '#'),
#    ('Water', 'Water')],
#   <map at 0x1a2b468550>),
#  ([('RT', 'rt'),
#    ('@F7hmayda', '@f7hmayda'),
#    (':', ':'),
#    ('@alshabab_visca', '@alshabab_visca'),
#    ('والله', 'والله'),
#    ('رغم', 'رغم'),
#    ('سوء', 'سوء'),
#    ('الحالة', 'الحالة'),
#    ('بالحي', 'بالحي'),
#    ('ونقص', 'ونقص'),
#    ('الماء', 'الماء'),
#    ('الصالح', 'الصالح'),
#    ('للشراب', 'للشراب')],
#   <map at 0x1a2b468668>),
#  ([('@alshabab_visca', '@alshabab_visca'),
#    ('والله', 'والله'),
#    ('رغم', 'رغم'),
#    ('سوء', 'سوء'),
#    ('الحالة', 'الحالة'),
#    ('بالحي', 'بالحي'),
#    ('ونقص', 'ونقص'),
#    ('الماء', 'الماء'),
#    ('الصالح', 'الصالح'),
#    ('للشراب', 'للشراب')],
#   <map at 0x1a2b4686a0>),
#  ([('الحق', 'الحق'),
#    ('في', 'في'),
#    ('الماء', 'الماء'),
#    ('الصالح', 'الصالح'),
#    ('للشراب', 'للشراب'),
#    ('https://t.co/8NByB34iQi', 'https://t.co/8nbyb34iqi')],
#   <map at 0x1a2b4686d8>),
#  ([('#', '#'),
#    ('Tunisie', 'tunisie'),
#    ('\n', '\n'),
#    ('Perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupures', 'coupure'),
#    ('de', 'de'),
#    ("l'", 'le'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('aux', 'aux'),
#    ('cités', 'citer'),
#    ('Ettadhamen', 'Ettadhamen'),
#    ('et', 'et'),
#    ('Douar', 'Douar'),
#    ('Hicher', 'Hicher'),
#    (',', ','),
#    ('la', 'le'),
#    ('reprise', 'reprise'),
#    ('est', 'être'),
#    ('prévue', 'prévoir'),
#    ('ce', 'ce'),
#    ('soir', 'soir'),
#    (',', ','),
#    ('selon', 'selon'),
#    ('la', 'le'),
#    ('#', '#'),
#    ('SONEDE', 'soned')],
#   <map at 0x1a2b46d048>),
#  ([('Jendouba', 'jendouba'),
#    (':', ':'),
#    ('70', '70'),
#    ('%', 'pourcent'),
#    ('des', 'un'),
#    ('projets', 'projet'),
#    ('d’', 'd’'),
#    ('approvisionnement', 'approvisionnemer'),
#    ('des', 'un'),
#    ('zones', 'zone'),
#    ('rurales', 'ruraler'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('seront', 'être'),
#    ('entamés', 'entamer'),
#    ('en', 'en'),
#    ('2019', '2019'),
#    ('https://t.co/EaDNDdhOdl', 'https://t.co/eadnddhodl')],
#   <map at 0x1a2b46d630>),
#  ([('Hamdullah', 'Hamdullah'),
#    (',', ','),
#    ('on', 'on'),
#    ('ne', 'ne'),
#    ('peut', 'pouvoir'),
#    ('que', 'que'),
#    ("s'", 'se'),
#    ('en', 'en'),
#    ('réjouir', 'réjouir'),
#    ('!', '!')],
#   <map at 0x1a2b46d978>),
#  ([('https://t.co/816XrdNDqg', 'https://t.co/816xrdndqg')],
#   <map at 0x1a2b46d9b0>),
#  ([('Et', 'et'),
#    ('puis', 'pouvoir'),
#    ('un', 'un'),
#    ('jour', 'jour'),
#    ('de', 'de'),
#    ('ramadan', 'ramadan'),
#    ('14h', '14h'),
#    ('et', 'et'),
#    ('27’c', '27’c'),
#    ('a', 'avoir'),
#    ('l’', 'l’'),
#    ('ombre', 'ombre'),
#    ('et', 'et'),
#    ('y’a', 'y’a'),
#    ('#', '#'),
#    ('Sonede', 'Sonede'),
#    ('qui', 'qui'),
#    ('nous', 'nous'),
#    ('programme', 'programme'),
#    (' ', ' '),
#    ('a', 'avoir'),
#    ('#', '#'),
#    ('Mourouj', 'Mourouj'),
#    ('une', 'un'),
#    ('coupure', 'coupure'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('nous', 'nous'),
#    ('laissant', 'laisser'),
#    ('comme', 'comme'),
#    ('toujours', 'toujours'),
#    ('seul', 'seul'),
#    ('face', 'face'),
#    ('à', 'à'),
#    ('notre', 'notre'),
#    ('destin', 'destin'),
#    ('sans', 'sans'),
#    ('préavis', 'préavi'),
#    ('ni', 'ni'),
#    ('rien', 'rien'),
#    ('du', 'de'),
#    ('tout', 'tout'),
#    ('#', '#'),
#    ('Tunisie', 'tunisie')],
#   <map at 0x1a2b475940>),
#  ([('@YoCh_Official', '@yoch_official'),
#    ('Si', 'si'),
#    ('Vs', 'vous'),
#    ('pouvez', 'pouvoir'),
#    ('me', 'me'),
#    ('répondre', 'répondre'),
#    ('sur', 'sur'),
#    ('mon', 'mon'),
#    ('projet', 'projet'),
#    ('de', 'de'),
#    ('dessalement', 'dessalement'),
#    ('de', 'de'),
#    ('Mahdia', 'Mahdia'),
#    ('basé', 'baser'),
#    ('sur', 'sur'),
#    ('100%d', '100%d'),
#    ('énergie', 'énergie'),
#    ('renouvelable', 'renouvelable'),
#    ('pour', 'pour'),
#    ('produire', 'produire'),
#    ('de', 'de'),
#    ('l', 'l'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('pour', 'pour'),
#    ('une', 'un'),
#    ('population', 'population'),
#    ('de', 'de'),
#    ('500.000', '500.000'),
#    ('habitants', 'habitant'),
#    ('...', '...'),
#    ('je', 'je'),
#    ('suis', 'être'),
#    ('Ds', 'ds'),
#    ('la', 'le'),
#    ('liste', 'liste'),
#    ('d', 'd'),
#    ('attente', 'attente'),
#    ('du', 'de'),
#    ('gouvernement', 'gouvernement'),
#    ('depuis', 'depuis'),
#    ('2016', '2016'),
#    ('...', '...'),
#    ('plutôt', 'plutôt'),
#    ('Ds', 'ds'),
#    ('la', 'le'),
#    ('liste', 'liste'),
#    ('de', 'de'),
#    ('blocage', 'blocage'),
#    ('.', '.')],
#   <map at 0x1a2b4729e8>),
#  ([('..', '..'), ('https://t.co/oFBBXzhOY8', 'https://t.co/ofbbxzhoy8')],
#   <map at 0x1a2b472b00>),
#  ([('Perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupures', 'coupure'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ('d’', 'd’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('à', 'à'),
#    ('Menzel', 'Menzel'),
#    ('\xa0', '  '),
#    ('Bouzayane', 'Bouzayane'),
#    ('https://t.co/bKP48ooI6u', 'https://t.co/bKP48ooI6u'),
#    ('https://t.co/ZNfUrd4v9N', 'https://t.co/znfurd4v9n')],
#   <map at 0x1a2b472eb8>),
#  ([('Tunisie', 'tunisie'),
#    (':', ':'),
#    ('Perturbations', 'perturbation'),
#    ('dans', 'dans'),
#    ('la', 'le'),
#    ('distribution', 'distribution'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('à', 'à'),
#    ('Menzel', 'Menzel'),
#    ('Bouzayane', 'Bouzayane'),
#    ('https://t.co/uXeRs3O5eH', 'https://t.co/uXeRs3O5eH')],
#   <map at 0x1a2b47d2b0>),
#  ([('RT', 'rt'),
#    ('@alisnoussi1', '@alisnoussi1'),
#    (':', ':'),
#    ('@YoCh_Official', '@yoch_official'),
#    ('Si', 'si'),
#    ('Vs', 'vous'),
#    ('pouvez', 'pouvoir'),
#    ('me', 'me'),
#    ('répondre', 'répondre'),
#    ('sur', 'sur'),
#    ('mon', 'mon'),
#    ('projet', 'projet'),
#    ('de', 'de'),
#    ('dessalement', 'dessalement'),
#    ('de', 'de'),
#    ('Mahdia', 'Mahdia'),
#    ('basé', 'baser'),
#    ('sur', 'sur'),
#    ('100%d', '100%d'),
#    ('énergie', 'énergie'),
#    ('renouvelable', 'renouvelable'),
#    ('pour', 'pour'),
#    ('p', 'p'),
#    ('…', '…')],
#   <map at 0x1a2b47d9b0>),
#  ([('En', 'en'),
#    ('#', '#'),
#    ('Afrique', 'Afrique'),
#    ('subsaharienne', 'subsaharien'),
#    (',', ','),
#    ('seulement', 'seulement'),
#    ('24', '24'),
#    ('%', 'pourcent'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('population', 'population'),
#    ('a', 'avoir'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('une', 'un'),
#    ('source', 'source'),
#    ('sûre', 'sûr'),
#    ('d’#eau', 'd’#eau'),
#    ('potable', 'potable'),
#    ('et', 'et'),
#    ('les', 'le'),
#    ('installations', 'installation'),
#    ('#', '#'),
#    ('sanitaires', 'sanitaire'),
#    ('de', 'de'),
#    ('base', 'base'),
#    ('–non', '–non'),
#    ('partagées', 'partager'),
#    ('avec', 'avec'),
#    ('d’', 'd’'),
#    ('autres', 'autre'),
#    ('foyers', 'foyer'),
#    ('-', '-'),
#    ('sont', 'être'),
#    ('réservées', 'réserver'),
#    ('à', 'à'),
#    ('28', '28'),
#    ('%', 'pourcent'),
#    ('de', 'de'),
#    ('la', 'le'),
#    ('population', 'population'),
#    ('.', '.')],
#   <map at 0x1a2b4832e8>),
#  ([('L’', 'l’'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('l’#eau', 'l’#eau'),
#    ('et', 'et'),
#    ('à', 'à'),
#    ("l'", 'le'),
#    ('assainissement', 'assainissement'),
#    ('est', 'être'),
#    ('un', 'un'),
#    ('#', '#'),
#    ('DroitHumain', 'droithumain'),
#    ('!', '!')],
#   <map at 0x1a2b483518>),
#  ([('@UN', '@UN'), ('https://t.co/FZIgcFftiG', 'https://t.co/fzigcfftig')],
#   <map at 0x1a2b483630>),
#  ([('RT', 'rt'),
#    ('@ACA_WeAdvocate', '@aca_weadvocate'),
#    (':', ':'),
#    ('L’', 'l’'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('et', 'et'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('assainissement', 'assainissement'),
#    ('est', 'être'),
#    ('reconnu', 'reconnaître'),
#    ('comme', 'comme'),
#    ('un', 'un'),
#    ('Droit', 'droit'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('homme', 'homme'),
#    ('depuis', 'depuis'),
#    ('2010', '2010'),
#    (',', ','),
#    ('mais', 'mais'),
#    ('près', 'près'),
#    ('de', 'de'),
#    ('3,5', '3,5'),
#    ('milli', 'milli'),
#    ('…', '…')],
#   <map at 0x1a2b483dd8>),
#  ([('RT', 'rt'),
#    ('@ACA_WeAdvocate', '@aca_weadvocate'),
#    (':', ':'),
#    ('L’', 'l’'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('et', 'et'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('assainissement', 'assainissement'),
#    ('est', 'être'),
#    ('reconnu', 'reconnaître'),
#    ('comme', 'comme'),
#    ('un', 'un'),
#    ('Droit', 'droit'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('homme', 'homme'),
#    ('depuis', 'depuis'),
#    ('2010', '2010'),
#    (',', ','),
#    ('mais', 'mais'),
#    ('près', 'près'),
#    ('de', 'de'),
#    ('3,5', '3,5'),
#    ('milli', 'milli'),
#    ('…', '…')],
#   <map at 0x1a2b4885c0>),
#  ([('RT', 'rt'),
#    ('@ACA_WeAdvocate', '@aca_weadvocate'),
#    (':', ':'),
#    ('L’', 'l’'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('et', 'et'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('assainissement', 'assainissement'),
#    ('est', 'être'),
#    ('reconnu', 'reconnaître'),
#    ('comme', 'comme'),
#    ('un', 'un'),
#    ('Droit', 'droit'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('homme', 'homme'),
#    ('depuis', 'depuis'),
#    ('2010', '2010'),
#    (',', ','),
#    ('mais', 'mais'),
#    ('près', 'près'),
#    ('de', 'de'),
#    ('3,5', '3,5'),
#    ('milli', 'milli'),
#    ('…', '…')],
#   <map at 0x1a2b488d68>),
#  ([('RT', 'rt'),
#    ('@ACA_WeAdvocate', '@aca_weadvocate'),
#    (':', ':'),
#    ('L’', 'l’'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('et', 'et'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('assainissement', 'assainissement'),
#    ('est', 'être'),
#    ('reconnu', 'reconnaître'),
#    ('comme', 'comme'),
#    ('un', 'un'),
#    ('Droit', 'droit'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('homme', 'homme'),
#    ('depuis', 'depuis'),
#    ('2010', '2010'),
#    (',', ','),
#    ('mais', 'mais'),
#    ('près', 'près'),
#    ('de', 'de'),
#    ('3,5', '3,5'),
#    ('milli', 'milli'),
#    ('…', '…')],
#   <map at 0x1a2b48d550>),
#  ([('L’', 'l’'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('et', 'et'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('assainissement', 'assainissement'),
#    ('est', 'être'),
#    ('reconnu', 'reconnaître'),
#    ('comme', 'comme'),
#    ('un', 'un'),
#    ('Droit', 'droit'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('homme', 'homme'),
#    ('depuis', 'depuis'),
#    ('2010', '2010'),
#    (',', ','),
#    ('mais', 'mais'),
#    ('près', 'près'),
#    ('de', 'de'),
#    ('3,5', '3,5'),
#    ('milliards', 'milliard'),
#    ('d’', 'd’'),
#    ('êtres', 'être'),
#    ('humains', 'humain'),
#    ('n’', 'n’'),
#    ('ont', 'avoir'),
#    (',', ','),
#    ('encore', 'encore'),
#    ('aujourd’hui', 'aujourd’hui'),
#    (',', ','),
#    ('d’', 'd’'),
#    ('autre', 'autre'),
#    ('choix', 'choix'),
#    ('que', 'que'),
#    ('de', 'de'),
#    ('boire', 'boire'),
#    ('une', 'un'),
#    ('eau', 'eau'),
#    ('dangereuse', 'dangereux'),
#    ('pour', 'pour'),
#    ('leur', 'son'),
#    ('santé', 'santé'),
#    ('.', '.')],
#   <map at 0x1a2b48a198>),
#  ([('2,4', '2,4'),
#    ('milliards', 'milliard'),
#    ('ne', 'ne'),
#    ('disposent', 'disposer'),
#    ('tjrs', 'tjrs'),
#    ('pas', 'pas'),
#    ('de', 'de'),
#    ('toilettes', 'toilette'),
#    ('.', '.')],
#   <map at 0x1a2b48a470>),
#  ([('https://t.co/2nC3IFHzkh', 'https://t.co/2nc3ifhzkh')],
#   <map at 0x1a2b48a4a8>),
#  ([('Reprise', 'reprise'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('au', 'au'),
#    ('Sud', 'Sud'),
#    ('tunisien', 'tunisien'),
#    ('https://t.co/kMu06ekNoJ', 'https://t.co/kmu06eknoj')],
#   <map at 0x1a2b48a8d0>),
#  ([('SONEDE', 'soned'),
#    (':', ':'),
#    ('Ben', 'Ben'),
#    ('Arous', 'Arous'),
#    ('et', 'et'),
#    ('Zaghouan', 'Zaghouan'),
#    ('sans', 'sans'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('https://t.co/OQlTBlP2uy', 'https://t.co/oqltblp2uy')],
#   <map at 0x1a2b48ac88>),
#  ([('Tunisie', 'tunisie'),
#    (':', ':'),
#    ('Des', 'un'),
#    ('perturbations', 'perturbation'),
#    ('et', 'et'),
#    ('coupures', 'coupure'),
#    ("d'", 'de'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('ces', 'ce'),
#    ('zones', 'zone'),
#    ('de', 'de'),
#    ('Tunis', 'Tunis'),
#    ('https://t.co/rsD24AWWtW', 'https://t.co/rsd24awwtw')],
#   <map at 0x1a2b494278>),
#  ([('Fourniture', 'fourniture'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('par', 'par'),
#    ('affermage', 'affermage'),
#    (':', ':'),
#    ('L’', 'l’'),
#    ('Etat', 'etat'),
#    ('béninois', 'béninois'),
#    ('sonde', 'sonde'),
#    ('des', 'un'),
#    ('investisseurs', 'investisseur'),
#    ('régionaux', 'régional'),
#    ('#', '#'),
#    ('Bénin', 'Bénin'),
#    ('|', '|'),
#    ('La', 'le'),
#    ('Nouvelle', 'nouvelle'),
#    ('Tribune', 'Tribune'),
#    ('https://t.co/PYRtvbhs6H', 'https://t.co/pyrtvbhs6h'),
#    ('@lntribune', '@lntribune')],
#   <map at 0x1a2b494710>),
#  ([('Gafsa', 'Gafsa'),
#    (':', ':'),
#    ('des', 'un'),
#    ('citoyens', 'citoyen'),
#    ('réclament', 'réclamer'),
#    ('l’', 'l’'),
#    ('accès', 'accès'),
#    ('à', 'à'),
#    ('l’', 'l’'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('(', '('),
#    ('Photos', 'photo'),
#    (')', ')'),
#    ('https://t.co/ijwLgrzj77', 'https://t.co/ijwlgrzj77')],
#   <map at 0x1a2b494a20>),
#  ([('Rétablissement', 'rétablissement'),
#    ('de', 'de'),
#    ('l’', 'l’'),
#    ('approvisionnement', 'approvisionnement'),
#    ('en', 'en'),
#    ('eau', 'eau'),
#    ('potable', 'potable'),
#    ('dans', 'dans'),
#    ('ces', 'ce'),
#    ('régions', 'région'),
#    ('https://t.co/9PQw3sqxa7', 'https://t.co/9pqw3sqxa7')],
#   <map at 0x1a2b494d68>),
#  ([('@M_Balsam', '@m_balsam'),
#    ('@rania_tn', '@rania_tn'),
#    ('نعم', 'نعم'),
#    ('،', '،'),
#    ('أخطأت', 'أخطأت'),
#    ('مكان', 'مكان'),
#    ('التعليق', 'التعليق'),
#    ('.', '.')],
#   <map at 0x1a2b494da0>),
#  ([('كتبت', 'كتبت'),
#    ('تفاعلا', 'تفاعلا'),
#    ('مع', 'مع'),
#    ('كلامكم', 'كلامكم'),
#    ('انتم', 'انتم'),
#    ('،', '،'),
#    ('أرى', 'أرى'),
#    ('أن', 'أن'),
#    ('بناء', 'بناء'),
#    ('مثل', 'مثل'),
#    ('هذه', 'هذه'),
#    ('المدارس', 'المدارس'),
#    ('لا', 'لا'),
#    ('فائدة', 'فائدة'),
#    ('منه', 'منه'),
#    ('خاصة', 'خاصة'),
#    ('مع', 'مع'),
#    ('الإنقطاع', 'الإنقطاع'),
#    ('المتكرر', 'المتكرر'),
#    ('للتيار', 'للتيار'),
#    ('الكهربائي', 'الكهربائي'),
#    ('و', 'و'),
#    ('الماء', 'الماء'),
#    ('الصالح', 'الصالح'),
#    ('للشراب', 'للشراب'),
#    ('حتى', 'حتى'),
#    ('في', 'في'),
#    ('العاصمة', 'العاصمة'),
#    ('.', '.')],
#   <map at 0x1a2b494dd8>)]

# %% [markdown]
# ## 2. Semantics
#
# Library for French language?

# %% [markdown]
# ### 2.1 POS tagging

# %% [markdown]
# ### 2.2 Chunking

# %% [markdown]
# ### 2.3 Dependency parsing

# %% [markdown]
# ### 2.4 Readability features

# %%
import textstat

# %%
no_url_tweets = remove_pattern_collection(tweets, url_pattern)

# %%
text = ''.join(no_url_tweets)
text
# Out:
# 'Les gouvernorats de Siliana, Kasserine et Jendouba souffrent de coupures de l’eau potable Perturbations et coupures de l’approvisionnement en eau potable dans les gouvernorats de Siliana, Kasserine et Jendouba L\'approvisionnement en eau potable reprendra, dans la nuit du mardi au mercredi... Perturbations et coupures dans l’approvisionnement en eau potable dans quelques régions à Jendouba et Béja Perturbations dans l’approvisionnement en eau potable dans quelques régions à Jendouba et Béjà La reprise sera progressive... "#Tunisie : Perturbations et coupures dans l’approvisionnement en eau potable à Jendouba et à Béja Tunisie - Tozeur : La SONEDE rassure sur la qualité de l’eau potable Nos gouvernants ont l\'habitude de prendre de l\'eau minérale pdt que les populations sont en quête de l\'eau potable. Les habitants d\'un village Kenyan ont servi de l\'eau sale aux autorités lors d\'une réunion. Cela doit servir de leçon à tous. #Centrafrique  Jendouba nord : le vol des équipements de la SONEDE prive plusieurs régions de l\'eau potable le vol des équipements de la SONEDE prive plusieurs régions de l’eau potable  Reprise cette nuit de l’approvisionnement en eau potable dans la région de Radès Selon un communiqué de la SONEDE... Malgré le retard dans la réalisation... Ariana : pertrubation de la distribution d\'eau potable dans plusieurs région demain à partir de 21h pertrubation de la distribution d’eau potable dans plusieurs région demain à partir de\xa021h  Tunisie: Perturbation de l\'approvisionnement en eau potable dans plusieurs zones de Raoued Une perturbation et une coupure dans l’approvisionnement en eau potable, seront enregistrées à partir du mardi 19 février 2019, à 21H, dans la délégation de #Raoued. #Tunis #Actualité  A partir de demain, mardi 19 février 2019... Les travaux se poursuivent pour assurer la reprise de l’approvisionnement en #eau potable à #Gafsa (SONEDE) Distribution de l\'eau potable : perturbations et coupure à Raoued ce soir  Les travaux se poursuivent pour assurer la reprise de l’approvisionnement en #eau potable à #Gafsa (SONEDE) A partir de demain, mardi 19 février 2019... Une perturbation et une coupure dans l’approvisionnement en eau potable, seront enregistrées à partir du mardi 19 février 2019, à 21H, dans la délégation de #Raoued. #Tunis #Actualité  Tunisie: Perturbation de l\'approvisionnement en eau potable dans plusieurs zones de Raoued pertrubation de la distribution d’eau potable dans plusieurs région demain à partir de\xa021h  Ariana : pertrubation de la distribution d\'eau potable dans plusieurs région demain à partir de 21h Malgré le retard dans la réalisation... Selon un communiqué de la SONEDE... Reprise cette nuit de l’approvisionnement en eau potable dans la région de Radès le vol des équipements de la SONEDE prive plusieurs régions de l’eau\xa0potable  Jendouba nord : le vol des équipements de la SONEDE prive plusieurs régions de l\'eau potable Nos gouvernants ont l\'habitude de prendre de l\'eau minérale pdt que les populations sont en quête de l\'eau potable. Les habitants d\'un village Kenyan ont servi de l\'eau sale aux autorités lors d\'une réunion. Cela doit servir de leçon à tous. #Centrafrique  A Fondouk Jedid, sit-in et arrêt de la pompe du canal Majerda desservant l\'eau potable Il s’agit d’un projet d’appui de la production de l’eau potable dans le Grand-Tunis avec une capacité de production de 100 mille m3 par jour. Le 2ème projet porte, en outre, sur la station du traitement des eaux usées avec une capacité de production... Le Grand Tunis n’aura plus de soucis d’eau potable Le Chef du gouvernement Youssef Chahed inaugure deux importants projets à Ghedir el Golla consacrés à l’eau potable Le Chef du gouvernement inaugure deux importants projets à Ghedir el Golla consacrés à l’eau potable | Tunivisions  via @TunivisionsRT @odilon236: #Centrafrique : le manque d\'eau potable dans les périphéries de Bangui devient un problème plus épineux que jamais.Il faut…Perturbati ...

# %%
textstat.flesch_reading_ease(text)
# Out:
# 44.95

# %%
textstat.smog_index(text)
# Out:
# 14.6

# %%
textstat.flesch_kincaid_grade(text)
# Out:
# 17.6

# %%
textstat.coleman_liau_index(text)
# Out:
# 13.25

# %%
textstat.automated_readability_index(text)
# Out:
# 25.2

# %%
textstat.dale_chall_readability_score(text)
# Out:
# 7.69

# %%
textstat.difficult_words(text)
# Out:
# 765

# %%
textstat.linsear_write_formula(text)
# Out:
# 34.0

# %%
textstat.gunning_fog(text)
# Out:
# 18.88

# %%
textstat.text_standard(text)
# Out:
# '17th and 18th grade'

# %% [markdown]
# ### 2.5 Topic modelling

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer

# %%
def clean(doc, lem=False):
    no_url = remove_pattern(doc,url_pattern)
    lower_doc = lower_case(no_url)
    no_punc_doc = remove_punctuation(lower_doc)
    # token_doc = tokenize_word(lower_doc) tokinezation has been already covered in remove_stopwords function
    # print(token_doc)
    no_stop_doc = remove_stopwords(no_punc_doc)
    #print(no_stop_doc)
    #no_url = remove_pattern(no_stop_doc,url_pattern)
    #print(no_stop_doc)
    clean = remove_pattern(no_stop_doc,nonalphanumeric_pattern) # letters with accent should be added to nonalphanumeric_pattern, otherwsie removed!
    #clean = no_stop_doc
    if lem:
        print(lemmatize(clean)[0])
        normalized = [w[1] for w in lemmatize(clean)[0]]
        return " ".join(normalized)
    else:
        return clean    
    
def clean_collection(docs, lem=False):
    clean_tweets = [clean(tw).split() for tw in tweets]
    return clean_tweets

# %%
doc = tweets[3]
doc
# Out:
# 'Perturbations et coupures dans l’approvisionnement en eau potable dans quelques régions à Jendouba et Béja https://t.co/qnFhE9rRU0'

# %%
clean(doc, True)
# Out:
# [('perturbations', 'perturbation'), ('coupures', 'coupure'), (' ', ' '), ('approvisionnement', 'approvisionnemer'), ('eau', 'eau'), ('potable', 'potable'), ('quelques', 'quelque'), ('régions', 'région'), ('jendouba', 'jendouba'), ('béja', 'béjer')]
# 'perturbation coupure   approvisionnemer eau potable quelque région jendouba béjer'

# %%
tweets_clean = clean_collection(tweets)

# %%
import gensim
from gensim import corpora, models

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(tweets_clean)
    
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(doc) for doc in tweets_clean]

# generate LDA model
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=2, id2word = dictionary, passes=20)

# %%
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
# [(0, '0.039*"eau" + 0.026*"potable" + 0.012*"rt"'), (1, '0.023*"leau" + 0.018*"potable" + 0.018*"les"')]

# %% [markdown]
# ### 2.6 N-grams

# %%
def generate_ngrams(text, n):
    words = text.split()
    output = []  
    for i in range(len(words)-n+1):
        output.append(words[i:i+n])
    return output

[generate_ngrams(tw, 2) for tw in tweets]
# Out:
# [[['Les', 'gouvernorats'],
#   ['gouvernorats', 'de'],
#   ['de', 'Siliana,'],
#   ['Siliana,', 'Kasserine'],
#   ['Kasserine', 'et'],
#   ['et', 'Jendouba'],
#   ['Jendouba', 'souffrent'],
#   ['souffrent', 'de'],
#   ['de', 'coupures'],
#   ['coupures', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'https://t.co/j0bbbzzVcp']],
#  [['Perturbations', 'et'],
#   ['et', 'coupures'],
#   ['coupures', 'de'],
#   ['de', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'gouvernorats'],
#   ['gouvernorats', 'de'],
#   ['de', 'Siliana,'],
#   ['Siliana,', 'Kasserine'],
#   ['Kasserine', 'et'],
#   ['et', 'Jendouba'],
#   ['Jendouba', 'https://t.co/3Sk2V370g0']],
#  [["L'approvisionnement", 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'reprendra,'],
#   ['reprendra,', 'dans'],
#   ['dans', 'la'],
#   ['la', 'nuit'],
#   ['nuit', 'du'],
#   ['du', 'mardi'],
#   ['mardi', 'au'],
#   ['au', 'mercredi...'],
#   ['mercredi...', 'https://t.co/hAFm4dmiCB']],
#  [['Perturbations', 'et'],
#   ['et', 'coupures'],
#   ['coupures', 'dans'],
#   ['dans', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'quelques'],
#   ['quelques', 'régions'],
#   ['régions', 'à'],
#   ['à', 'Jendouba'],
#   ['Jendouba', 'et'],
#   ['et', 'Béja'],
#   ['Béja', 'https://t.co/qnFhE9rRU0']],
#  [['Perturbations', 'dans'],
#   ['dans', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'quelques'],
#   ['quelques', 'régions'],
#   ['régions', 'à'],
#   ['à', 'Jendouba'],
#   ['Jendouba', 'et'],
#   ['et', 'Béjà'],
#   ['Béjà', 'https://t.co/Hppav3y7sv']],
#  [['La', 'reprise'],
#   ['reprise', 'sera'],
#   ['sera', 'progressive...'],
#   ['progressive...', 'https://t.co/6hRuGbJuy7"']],
#  [['#Tunisie', ':'],
#   [':', 'Perturbations'],
#   ['Perturbations', 'et'],
#   ['et', 'coupures'],
#   ['coupures', 'dans'],
#   ['dans', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'à'],
#   ['à', 'Jendouba'],
#   ['Jendouba', 'et'],
#   ['et', 'à'],
#   ['à', 'Béja'],
#   ['Béja', 'https://t.co/34u2zoGUZ0']],
#  [['Tunisie', '-'],
#   ['-', 'Tozeur'],
#   ['Tozeur', ':'],
#   [':', 'La'],
#   ['La', 'SONEDE'],
#   ['SONEDE', 'rassure'],
#   ['rassure', 'sur'],
#   ['sur', 'la'],
#   ['la', 'qualité'],
#   ['qualité', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'https://t.co/8kKk0aEvCI']],
#  [['Nos', 'gouvernants'],
#   ['gouvernants', 'ont'],
#   ['ont', "l'habitude"],
#   ["l'habitude", 'de'],
#   ['de', 'prendre'],
#   ['prendre', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'minérale'],
#   ['minérale', 'pdt'],
#   ['pdt', 'que'],
#   ['que', 'les'],
#   ['les', 'populations'],
#   ['populations', 'sont'],
#   ['sont', 'en'],
#   ['en', 'quête'],
#   ['quête', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable.'],
#   ['potable.', 'Les'],
#   ['Les', 'habitants'],
#   ['habitants', "d'un"],
#   ["d'un", 'village'],
#   ['village', 'Kenyan'],
#   ['Kenyan', 'ont'],
#   ['ont', 'servi'],
#   ['servi', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'sale'],
#   ['sale', 'aux'],
#   ['aux', 'autorités'],
#   ['autorités', 'lors'],
#   ['lors', "d'une"],
#   ["d'une", 'réunion.'],
#   ['réunion.', 'Cela'],
#   ['Cela', 'doit'],
#   ['doit', 'servir'],
#   ['servir', 'de'],
#   ['de', 'leçon'],
#   ['leçon', 'à'],
#   ['à', 'tous.'],
#   ['tous.', '#Centrafrique'],
#   ['#Centrafrique', 'https://t.co/weB3WnXdWO'],
#   ['https://t.co/weB3WnXdWO', 'https://t.co/agUbx3Upsw']],
#  [['Jendouba', 'nord'],
#   ['nord', ':'],
#   [':', 'le'],
#   ['le', 'vol'],
#   ['vol', 'des'],
#   ['des', 'équipements'],
#   ['équipements', 'de'],
#   ['de', 'la'],
#   ['la', 'SONEDE'],
#   ['SONEDE', 'prive'],
#   ['prive', 'plusieurs'],
#   ['plusieurs', 'régions'],
#   ['régions', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'https://t.co/CiiImo2QRI']],
#  [['le', 'vol'],
#   ['vol', 'des'],
#   ['des', 'équipements'],
#   ['équipements', 'de'],
#   ['de', 'la'],
#   ['la', 'SONEDE'],
#   ['SONEDE', 'prive'],
#   ['prive', 'plusieurs'],
#   ['plusieurs', 'régions'],
#   ['régions', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'https://t.co/K4PykDFykw'],
#   ['https://t.co/K4PykDFykw', 'https://t.co/dqXYeFItXt']],
#  [['Reprise', 'cette'],
#   ['cette', 'nuit'],
#   ['nuit', 'de'],
#   ['de', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'la'],
#   ['la', 'région'],
#   ['région', 'de'],
#   ['de', 'Radès'],
#   ['Radès', 'https://t.co/nAbyJ0Mqdz']],
#  [['Selon', 'un'],
#   ['un', 'communiqué'],
#   ['communiqué', 'de'],
#   ['de', 'la'],
#   ['la', 'SONEDE...'],
#   ['SONEDE...', 'https://t.co/cgb39AfWeF']],
#  [['Malgré', 'le'],
#   ['le', 'retard'],
#   ['retard', 'dans'],
#   ['dans', 'la'],
#   ['la', 'réalisation...'],
#   ['réalisation...', 'https://t.co/DJczsEnscn']],
#  [['Ariana', ':'],
#   [':', 'pertrubation'],
#   ['pertrubation', 'de'],
#   ['de', 'la'],
#   ['la', 'distribution'],
#   ['distribution', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'plusieurs'],
#   ['plusieurs', 'région'],
#   ['région', 'demain'],
#   ['demain', 'à'],
#   ['à', 'partir'],
#   ['partir', 'de'],
#   ['de', '21h'],
#   ['21h', 'https://t.co/Pq0ZUtk7l1']],
#  [['pertrubation', 'de'],
#   ['de', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'plusieurs'],
#   ['plusieurs', 'région'],
#   ['région', 'demain'],
#   ['demain', 'à'],
#   ['à', 'partir'],
#   ['partir', 'de'],
#   ['de', '21h'],
#   ['21h', 'https://t.co/dzVjN9MQR4'],
#   ['https://t.co/dzVjN9MQR4', 'https://t.co/3uDgWNfKPk']],
#  [['Tunisie:', 'Perturbation'],
#   ['Perturbation', 'de'],
#   ['de', "l'approvisionnement"],
#   ["l'approvisionnement", 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'plusieurs'],
#   ['plusieurs', 'zones'],
#   ['zones', 'de'],
#   ['de', 'Raoued'],
#   ['Raoued', 'https://t.co/mW0QM8suaz']],
#  [['Une', 'perturbation'],
#   ['perturbation', 'et'],
#   ['et', 'une'],
#   ['une', 'coupure'],
#   ['coupure', 'dans'],
#   ['dans', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable,'],
#   ['potable,', 'seront'],
#   ['seront', 'enregistrées'],
#   ['enregistrées', 'à'],
#   ['à', 'partir'],
#   ['partir', 'du'],
#   ['du', 'mardi'],
#   ['mardi', '19'],
#   ['19', 'février'],
#   ['février', '2019,'],
#   ['2019,', 'à'],
#   ['à', '21H,'],
#   ['21H,', 'dans'],
#   ['dans', 'la'],
#   ['la', 'délégation'],
#   ['délégation', 'de'],
#   ['de', '#Raoued.'],
#   ['#Raoued.', '#Tunis'],
#   ['#Tunis', '#Actualité'],
#   ['#Actualité', 'https://t.co/gPZjeEFBwS'],
#   ['https://t.co/gPZjeEFBwS', 'https://t.co/KGuRRRc1l2']],
#  [['A', 'partir'],
#   ['partir', 'de'],
#   ['de', 'demain,'],
#   ['demain,', 'mardi'],
#   ['mardi', '19'],
#   ['19', 'février'],
#   ['février', '2019...'],
#   ['2019...', 'https://t.co/XJC4x3GCFK']],
#  [['Les', 'travaux'],
#   ['travaux', 'se'],
#   ['se', 'poursuivent'],
#   ['poursuivent', 'pour'],
#   ['pour', 'assurer'],
#   ['assurer', 'la'],
#   ['la', 'reprise'],
#   ['reprise', 'de'],
#   ['de', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', '#eau'],
#   ['#eau', 'potable'],
#   ['potable', 'à'],
#   ['à', '#Gafsa'],
#   ['#Gafsa', '(SONEDE)'],
#   ['(SONEDE)', 'https://t.co/GnvMp3DT3a']],
#  [['Distribution', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', ':'],
#   [':', 'perturbations'],
#   ['perturbations', 'et'],
#   ['et', 'coupure'],
#   ['coupure', 'à'],
#   ['à', 'Raoued'],
#   ['Raoued', 'ce'],
#   ['ce', 'soir'],
#   ['soir', 'https://t.co/7Yms5Qybde'],
#   ['https://t.co/7Yms5Qybde', 'https://t.co/VYidVPAQFI']],
#  [['Les', 'travaux'],
#   ['travaux', 'se'],
#   ['se', 'poursuivent'],
#   ['poursuivent', 'pour'],
#   ['pour', 'assurer'],
#   ['assurer', 'la'],
#   ['la', 'reprise'],
#   ['reprise', 'de'],
#   ['de', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', '#eau'],
#   ['#eau', 'potable'],
#   ['potable', 'à'],
#   ['à', '#Gafsa'],
#   ['#Gafsa', '(SONEDE)'],
#   ['(SONEDE)', 'https://t.co/GnvMp3DT3a']],
#  [['A', 'partir'],
#   ['partir', 'de'],
#   ['de', 'demain,'],
#   ['demain,', 'mardi'],
#   ['mardi', '19'],
#   ['19', 'février'],
#   ['février', '2019...'],
#   ['2019...', 'https://t.co/XJC4x3GCFK']],
#  [['Une', 'perturbation'],
#   ['perturbation', 'et'],
#   ['et', 'une'],
#   ['une', 'coupure'],
#   ['coupure', 'dans'],
#   ['dans', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable,'],
#   ['potable,', 'seront'],
#   ['seront', 'enregistrées'],
#   ['enregistrées', 'à'],
#   ['à', 'partir'],
#   ['partir', 'du'],
#   ['du', 'mardi'],
#   ['mardi', '19'],
#   ['19', 'février'],
#   ['février', '2019,'],
#   ['2019,', 'à'],
#   ['à', '21H,'],
#   ['21H,', 'dans'],
#   ['dans', 'la'],
#   ['la', 'délégation'],
#   ['délégation', 'de'],
#   ['de', '#Raoued.'],
#   ['#Raoued.', '#Tunis'],
#   ['#Tunis', '#Actualité'],
#   ['#Actualité', 'https://t.co/gPZjeEFBwS'],
#   ['https://t.co/gPZjeEFBwS', 'https://t.co/KGuRRRc1l2']],
#  [['Tunisie:', 'Perturbation'],
#   ['Perturbation', 'de'],
#   ['de', "l'approvisionnement"],
#   ["l'approvisionnement", 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'plusieurs'],
#   ['plusieurs', 'zones'],
#   ['zones', 'de'],
#   ['de', 'Raoued'],
#   ['Raoued', 'https://t.co/mW0QM8suaz']],
#  [['pertrubation', 'de'],
#   ['de', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'plusieurs'],
#   ['plusieurs', 'région'],
#   ['région', 'demain'],
#   ['demain', 'à'],
#   ['à', 'partir'],
#   ['partir', 'de'],
#   ['de', '21h'],
#   ['21h', 'https://t.co/dzVjN9MQR4'],
#   ['https://t.co/dzVjN9MQR4', 'https://t.co/3uDgWNfKPk']],
#  [['Ariana', ':'],
#   [':', 'pertrubation'],
#   ['pertrubation', 'de'],
#   ['de', 'la'],
#   ['la', 'distribution'],
#   ['distribution', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'plusieurs'],
#   ['plusieurs', 'région'],
#   ['région', 'demain'],
#   ['demain', 'à'],
#   ['à', 'partir'],
#   ['partir', 'de'],
#   ['de', '21h'],
#   ['21h', 'https://t.co/Pq0ZUtk7l1']],
#  [['Malgré', 'le'],
#   ['le', 'retard'],
#   ['retard', 'dans'],
#   ['dans', 'la'],
#   ['la', 'réalisation...'],
#   ['réalisation...', 'https://t.co/DJczsEnscn']],
#  [['Selon', 'un'],
#   ['un', 'communiqué'],
#   ['communiqué', 'de'],
#   ['de', 'la'],
#   ['la', 'SONEDE...'],
#   ['SONEDE...', 'https://t.co/cgb39AfWeF']],
#  [['Reprise', 'cette'],
#   ['cette', 'nuit'],
#   ['nuit', 'de'],
#   ['de', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'la'],
#   ['la', 'région'],
#   ['région', 'de'],
#   ['de', 'Radès'],
#   ['Radès', 'https://t.co/nAbyJ0Mqdz']],
#  [['le', 'vol'],
#   ['vol', 'des'],
#   ['des', 'équipements'],
#   ['équipements', 'de'],
#   ['de', 'la'],
#   ['la', 'SONEDE'],
#   ['SONEDE', 'prive'],
#   ['prive', 'plusieurs'],
#   ['plusieurs', 'régions'],
#   ['régions', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'https://t.co/K4PykDFykw'],
#   ['https://t.co/K4PykDFykw', 'https://t.co/dqXYeFItXt']],
#  [['Jendouba', 'nord'],
#   ['nord', ':'],
#   [':', 'le'],
#   ['le', 'vol'],
#   ['vol', 'des'],
#   ['des', 'équipements'],
#   ['équipements', 'de'],
#   ['de', 'la'],
#   ['la', 'SONEDE'],
#   ['SONEDE', 'prive'],
#   ['prive', 'plusieurs'],
#   ['plusieurs', 'régions'],
#   ['régions', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'https://t.co/CiiImo2QRI']],
#  [['Nos', 'gouvernants'],
#   ['gouvernants', 'ont'],
#   ['ont', "l'habitude"],
#   ["l'habitude", 'de'],
#   ['de', 'prendre'],
#   ['prendre', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'minérale'],
#   ['minérale', 'pdt'],
#   ['pdt', 'que'],
#   ['que', 'les'],
#   ['les', 'populations'],
#   ['populations', 'sont'],
#   ['sont', 'en'],
#   ['en', 'quête'],
#   ['quête', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable.'],
#   ['potable.', 'Les'],
#   ['Les', 'habitants'],
#   ['habitants', "d'un"],
#   ["d'un", 'village'],
#   ['village', 'Kenyan'],
#   ['Kenyan', 'ont'],
#   ['ont', 'servi'],
#   ['servi', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'sale'],
#   ['sale', 'aux'],
#   ['aux', 'autorités'],
#   ['autorités', 'lors'],
#   ['lors', "d'une"],
#   ["d'une", 'réunion.'],
#   ['réunion.', 'Cela'],
#   ['Cela', 'doit'],
#   ['doit', 'servir'],
#   ['servir', 'de'],
#   ['de', 'leçon'],
#   ['leçon', 'à'],
#   ['à', 'tous.'],
#   ['tous.', '#Centrafrique'],
#   ['#Centrafrique', 'https://t.co/weB3WnXdWO'],
#   ['https://t.co/weB3WnXdWO', 'https://t.co/agUbx3Upsw']],
#  [['A', 'Fondouk'],
#   ['Fondouk', 'Jedid,'],
#   ['Jedid,', 'sit-in'],
#   ['sit-in', 'et'],
#   ['et', 'arrêt'],
#   ['arrêt', 'de'],
#   ['de', 'la'],
#   ['la', 'pompe'],
#   ['pompe', 'du'],
#   ['du', 'canal'],
#   ['canal', 'Majerda'],
#   ['Majerda', 'desservant'],
#   ['desservant', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'https://t.co/Oi2vBIMfqP']],
#  [['Il', 's’agit'],
#   ['s’agit', 'd’un'],
#   ['d’un', 'projet'],
#   ['projet', 'd’appui'],
#   ['d’appui', 'de'],
#   ['de', 'la'],
#   ['la', 'production'],
#   ['production', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'le'],
#   ['le', 'Grand-Tunis'],
#   ['Grand-Tunis', 'avec'],
#   ['avec', 'une'],
#   ['une', 'capacité'],
#   ['capacité', 'de'],
#   ['de', 'production'],
#   ['production', 'de'],
#   ['de', '100'],
#   ['100', 'mille'],
#   ['mille', 'm3'],
#   ['m3', 'par'],
#   ['par', 'jour.'],
#   ['jour.', 'Le'],
#   ['Le', '2ème'],
#   ['2ème', 'projet'],
#   ['projet', 'porte,'],
#   ['porte,', 'en'],
#   ['en', 'outre,'],
#   ['outre,', 'sur'],
#   ['sur', 'la'],
#   ['la', 'station'],
#   ['station', 'du'],
#   ['du', 'traitement'],
#   ['traitement', 'des'],
#   ['des', 'eaux'],
#   ['eaux', 'usées'],
#   ['usées', 'avec'],
#   ['avec', 'une'],
#   ['une', 'capacité'],
#   ['capacité', 'de'],
#   ['de', 'production...'],
#   ['production...', 'https://t.co/gP44Ij6eF6']],
#  [['Le', 'Grand'],
#   ['Grand', 'Tunis'],
#   ['Tunis', 'n’aura'],
#   ['n’aura', 'plus'],
#   ['plus', 'de'],
#   ['de', 'soucis'],
#   ['soucis', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', 'https://t.co/I14KyCL4u4']],
#  [['Le', 'Chef'],
#   ['Chef', 'du'],
#   ['du', 'gouvernement'],
#   ['gouvernement', 'Youssef'],
#   ['Youssef', 'Chahed'],
#   ['Chahed', 'inaugure'],
#   ['inaugure', 'deux'],
#   ['deux', 'importants'],
#   ['importants', 'projets'],
#   ['projets', 'à'],
#   ['à', 'Ghedir'],
#   ['Ghedir', 'el'],
#   ['el', 'Golla'],
#   ['Golla', 'consacrés'],
#   ['consacrés', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'https://t.co/45kmZaWbr4']],
#  [['Le', 'Chef'],
#   ['Chef', 'du'],
#   ['du', 'gouvernement'],
#   ['gouvernement', 'inaugure'],
#   ['inaugure', 'deux'],
#   ['deux', 'importants'],
#   ['importants', 'projets'],
#   ['projets', 'à'],
#   ['à', 'Ghedir'],
#   ['Ghedir', 'el'],
#   ['el', 'Golla'],
#   ['Golla', 'consacrés'],
#   ['consacrés', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', '|'],
#   ['|', 'Tunivisions'],
#   ['Tunivisions', 'https://t.co/GTxP6i5HEg'],
#   ['https://t.co/GTxP6i5HEg', 'via'],
#   ['via', '@Tunivisions']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#Centrafrique'],
#   ['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.Il'],
#   ['jamais.Il', 'faut…']],
#  [['Perturbation', 'de'],
#   ['de', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'la'],
#   ['la', 'zone'],
#   ['zone', 'inférieure'],
#   ['inférieure', 'à'],
#   ['à', 'Utique'],
#   ['Utique', 'ville'],
#   ['ville', 'https://t.co/0wZ7AKliWu'],
#   ['https://t.co/0wZ7AKliWu', 'https://t.co/jbPB7AjhU8']],
#  [['Utique', ':'],
#   [':', 'Perturbations'],
#   ['Perturbations', 'et'],
#   ['et', 'coupures'],
#   ['coupures', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', '|'],
#   ['|', 'RTCI'],
#   ['RTCI', '-'],
#   ['-', 'Radio'],
#   ['Radio', 'Tunis'],
#   ['Tunis', 'Chaîne'],
#   ['Chaîne', 'Internationale'],
#   ['Internationale', 'https://t.co/IM5dYzadB2']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#Centrafrique'],
#   ['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut…']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#Centrafrique'],
#   ['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut…']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#Centrafrique'],
#   ['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut…']],
#  [['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut'],
#   ['faut', 'trouver'],
#   ['trouver', 'une'],
#   ['une', 'alternative'],
#   ['alternative', 'à'],
#   ['à', 'la'],
#   ['la', '#Sodeca'],
#   ['#Sodeca', 'qui'],
#   ['qui', 'ne'],
#   ['ne', 'parvient'],
#   ['parvient', 'pas'],
#   ['pas', 'à'],
#   ['à', 'satisfaire'],
#   ['satisfaire', 'le'],
#   ['le', 'besoin'],
#   ['besoin', 'de'],
#   ['de', 'ses'],
#   ['ses', 'clients.'],
#   ['clients.', 'Ayez'],
#   ['Ayez', 'pitié'],
#   ['pitié', 'de'],
#   ['de', 'ses'],
#   ['ses', 'mères'],
#   ['mères', "d'enfants!"],
#   ["d'enfants!", '@GouvCF'],
#   ['@GouvCF', '@RJDH_RCA'],
#   ['@RJDH_RCA', 'https://t.co/EUVe2AEYI1']],
#  [['Samir', 'Taieb'],
#   ['Taieb', ':'],
#   [':', 'un'],
#   ['un', 'plan'],
#   ['plan', 'national'],
#   ['national', 'mis'],
#   ['mis', 'en'],
#   ['en', 'place'],
#   ['place', 'pour'],
#   ['pour', 'sécuriser'],
#   ['sécuriser', 'approvisionnement'],
#   ['approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'durant'],
#   ['durant', 'l’été'],
#   ['l’été', '2019'],
#   ['2019', 'https://t.co/Ldm9kbixqp'],
#   ['https://t.co/Ldm9kbixqp', 'https://t.co/cj3VX8iD1J']],
#  [['A', 'Fondouk'],
#   ['Fondouk', 'Jedid,'],
#   ['Jedid,', 'sit-in'],
#   ['sit-in', 'et'],
#   ['et', 'arrêt'],
#   ['arrêt', 'de'],
#   ['de', 'la'],
#   ['la', 'pompe'],
#   ['pompe', 'du'],
#   ['du', 'canal'],
#   ['canal', 'Majerda'],
#   ['Majerda', 'desservant'],
#   ['desservant', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'https://t.co/Oi2vBIMfqP']],
#  [['Consommation', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'le'],
#   ['le', 'secteur'],
#   ['secteur', 'touristique'],
#   ['touristique', ':'],
#   [':', '611'],
#   ['611', 'Litres'],
#   ['Litres', 'par'],
#   ['par', 'Jour'],
#   ['Jour', 'et'],
#   ['et', 'par'],
#   ['par', 'lit'],
#   ['lit', 'occupé.'],
#   ['occupé.', 'Telle'],
#   ['Telle', 'une'],
#   ['une', 'douche'],
#   ['douche', 'froide'],
#   ['froide', 'sachant'],
#   ['sachant', 'que'],
#   ['que', 'pour'],
#   ['pour', 'remplir'],
#   ['remplir', 'une'],
#   ['une', 'baignoire,'],
#   ['baignoire,', 'il'],
#   ['il', 'faudrait'],
#   ['faudrait', '200'],
#   ['200', 'litres'],
#   ['litres', 'd’eau'],
#   ['d’eau', 'au'],
#   ['au', 'plus.'],
#   ['plus.', 'Source'],
#   ['Source', ':'],
#   [':', 'https://t.co/sISUlc2URZ.'],
#   ['https://t.co/sISUlc2URZ.', 'Détails:'],
#   ['Détails:', 'https://t.co/dXFEQv2htF'],
#   ['https://t.co/dXFEQv2htF', 'https://t.co/ZrCtT4xlvW']],
#  [['A', 'Fondouk'],
#   ['Fondouk', 'Jedid,'],
#   ['Jedid,', 'sit-in'],
#   ['sit-in', 'et'],
#   ['et', 'arrêt'],
#   ['arrêt', 'de'],
#   ['de', 'la'],
#   ['la', 'pompe'],
#   ['pompe', 'du'],
#   ['du', 'canal'],
#   ['canal', 'Majerda'],
#   ['Majerda', 'desservant'],
#   ['desservant', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'https://t.co/Oi2vBIMfqP']],
#  [['Il', 's’agit'],
#   ['s’agit', 'd’un'],
#   ['d’un', 'projet'],
#   ['projet', 'd’appui'],
#   ['d’appui', 'de'],
#   ['de', 'la'],
#   ['la', 'production'],
#   ['production', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'le'],
#   ['le', 'Grand-Tunis'],
#   ['Grand-Tunis', 'avec'],
#   ['avec', 'une'],
#   ['une', 'capacité'],
#   ['capacité', 'de'],
#   ['de', 'production'],
#   ['production', 'de'],
#   ['de', '100'],
#   ['100', 'mille'],
#   ['mille', 'm3'],
#   ['m3', 'par'],
#   ['par', 'jour.'],
#   ['jour.', 'Le'],
#   ['Le', '2ème'],
#   ['2ème', 'projet'],
#   ['projet', 'porte,'],
#   ['porte,', 'en'],
#   ['en', 'outre,'],
#   ['outre,', 'sur'],
#   ['sur', 'la'],
#   ['la', 'station'],
#   ['station', 'du'],
#   ['du', 'traitement'],
#   ['traitement', 'des'],
#   ['des', 'eaux'],
#   ['eaux', 'usées'],
#   ['usées', 'avec'],
#   ['avec', 'une'],
#   ['une', 'capacité'],
#   ['capacité', 'de'],
#   ['de', 'production...'],
#   ['production...', 'https://t.co/gP44Ij6eF6']],
#  [['Le', 'Grand'],
#   ['Grand', 'Tunis'],
#   ['Tunis', 'n’aura'],
#   ['n’aura', 'plus'],
#   ['plus', 'de'],
#   ['de', 'soucis'],
#   ['soucis', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', 'https://t.co/I14KyCL4u4']],
#  [['Le', 'Chef'],
#   ['Chef', 'du'],
#   ['du', 'gouvernement'],
#   ['gouvernement', 'Youssef'],
#   ['Youssef', 'Chahed'],
#   ['Chahed', 'inaugure'],
#   ['inaugure', 'deux'],
#   ['deux', 'importants'],
#   ['importants', 'projets'],
#   ['projets', 'à'],
#   ['à', 'Ghedir'],
#   ['Ghedir', 'el'],
#   ['el', 'Golla'],
#   ['Golla', 'consacrés'],
#   ['consacrés', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'https://t.co/45kmZaWbr4']],
#  [['Le', 'Chef'],
#   ['Chef', 'du'],
#   ['du', 'gouvernement'],
#   ['gouvernement', 'inaugure'],
#   ['inaugure', 'deux'],
#   ['deux', 'importants'],
#   ['importants', 'projets'],
#   ['projets', 'à'],
#   ['à', 'Ghedir'],
#   ['Ghedir', 'el'],
#   ['el', 'Golla'],
#   ['Golla', 'consacrés'],
#   ['consacrés', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', '|'],
#   ['|', 'Tunivisions'],
#   ['Tunivisions', 'https://t.co/GTxP6i5HEg'],
#   ['https://t.co/GTxP6i5HEg', 'via'],
#   ['via', '@Tunivisions']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#Centrafrique'],
#   ['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut…']],
#  [['Perturbation', 'de'],
#   ['de', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'la'],
#   ['la', 'zone'],
#   ['zone', 'inférieure'],
#   ['inférieure', 'à'],
#   ['à', 'Utique'],
#   ['Utique', 'ville'],
#   ['ville', 'https://t.co/0wZ7AKliWu'],
#   ['https://t.co/0wZ7AKliWu', 'https://t.co/jbPB7AjhU8']],
#  [['Utique', ':'],
#   [':', 'Perturbations'],
#   ['Perturbations', 'et'],
#   ['et', 'coupures'],
#   ['coupures', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', '|'],
#   ['|', 'RTCI'],
#   ['RTCI', '-'],
#   ['-', 'Radio'],
#   ['Radio', 'Tunis'],
#   ['Tunis', 'Chaîne'],
#   ['Chaîne', 'Internationale'],
#   ['Internationale', 'https://t.co/IM5dYzadB2']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#Centrafrique'],
#   ['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut…']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#Centrafrique'],
#   ['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut…']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#Centrafrique'],
#   ['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut…']],
#  [['#Centrafrique', ':'],
#   [':', 'le'],
#   ['le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'périphéries'],
#   ['périphéries', 'de'],
#   ['de', 'Bangui'],
#   ['Bangui', 'devient'],
#   ['devient', 'un'],
#   ['un', 'problème'],
#   ['problème', 'plus'],
#   ['plus', 'épineux'],
#   ['épineux', 'que'],
#   ['que', 'jamais.'],
#   ['jamais.', 'Il'],
#   ['Il', 'faut'],
#   ['faut', 'trouver'],
#   ['trouver', 'une'],
#   ['une', 'alternative'],
#   ['alternative', 'à'],
#   ['à', 'la'],
#   ['la', '#Sodeca'],
#   ['#Sodeca', 'qui'],
#   ['qui', 'ne'],
#   ['ne', 'parvient'],
#   ['parvient', 'pas'],
#   ['pas', 'à'],
#   ['à', 'satisfaire'],
#   ['satisfaire', 'le'],
#   ['le', 'besoin'],
#   ['besoin', 'de'],
#   ['de', 'ses'],
#   ['ses', 'clients.'],
#   ['clients.', 'Ayez'],
#   ['Ayez', 'pitié'],
#   ['pitié', 'de'],
#   ['de', 'ses'],
#   ['ses', 'mères'],
#   ['mères', "d'enfants!"],
#   ["d'enfants!", '@GouvCF'],
#   ['@GouvCF', '@RJDH_RCA'],
#   ['@RJDH_RCA', 'https://t.co/EUVe2AEYI1']],
#  [['Samir', 'Taieb'],
#   ['Taieb', ':'],
#   [':', 'un'],
#   ['un', 'plan'],
#   ['plan', 'national'],
#   ['national', 'mis'],
#   ['mis', 'en'],
#   ['en', 'place'],
#   ['place', 'pour'],
#   ['pour', 'sécuriser'],
#   ['sécuriser', 'approvisionnement'],
#   ['approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'durant'],
#   ['durant', 'l’été'],
#   ['l’été', '2019'],
#   ['2019', 'https://t.co/Ldm9kbixqp'],
#   ['https://t.co/Ldm9kbixqp', 'https://t.co/cj3VX8iD1J']],
#  [['RT', '@WATCHWATER_TN:'],
#   ['@WATCHWATER_TN:', 'Moyenne'],
#   ['Moyenne', 'de'],
#   ['de', 'la'],
#   ['la', 'Consommation'],
#   ['Consommation', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'le'],
#   ['le', 'secteur'],
#   ['secteur', 'touristique'],
#   ['touristique', ':'],
#   [':', '611'],
#   ['611', 'Litres'],
#   ['Litres', 'par'],
#   ['par', 'Jour'],
#   ['Jour', 'et'],
#   ['et', 'par'],
#   ['par', 'lit'],
#   ['lit', '/'],
#   ['/', 'personne.'],
#   ['personne.', 'Un…']],
#  [['Moyenne', 'de'],
#   ['de', 'la'],
#   ['la', 'Consommation'],
#   ['Consommation', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'le'],
#   ['le', 'secteur'],
#   ['secteur', 'touristique'],
#   ['touristique', ':'],
#   [':', '611'],
#   ['611', 'Litres'],
#   ['Litres', 'par'],
#   ['par', 'Jour'],
#   ['Jour', 'et'],
#   ['et', 'par'],
#   ['par', 'lit'],
#   ['lit', '/'],
#   ['/', 'personne.'],
#   ['personne.', 'Un'],
#   ['Un', 'chiffre'],
#   ['chiffre', 'qui'],
#   ['qui', 'donne'],
#   ['donne', 'froid'],
#   ['froid', 'au'],
#   ['au', 'dos'],
#   ['dos', 'sachant'],
#   ['sachant', 'que'],
#   ['que', 'pour'],
#   ['pour', 'remplir'],
#   ['remplir', 'une'],
#   ['une', 'baignoire,'],
#   ['baignoire,', 'il'],
#   ['il', 'faudrait'],
#   ['faudrait', '200...'],
#   ['200...', 'https://t.co/kJvElUHf5I']],
#  [['@ikrmch_', 'C’est'],
#   ['C’est', 'le'],
#   ['le', 'pire'],
#   ['pire', 'peuple.'],
#   ['peuple.', 'Imagine'],
#   ['Imagine', 't’es'],
#   ['t’es', 'milliardaire,'],
#   ['milliardaire,', 'tu'],
#   ['tu', 'peux'],
#   ['peux', 'développer'],
#   ['développer', 'l’accès'],
#   ['l’accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'plein'],
#   ['plein', 'de'],
#   ['de', 'pays,'],
#   ['pays,', 'mais'],
#   ['mais', 'tu'],
#   ['tu', 'préfères'],
#   ['préfères', 'payer'],
#   ['payer', 'une'],
#   ['une', 'babtou'],
#   ['babtou', 'pour'],
#   ['pour', 'qu’elle'],
#   ['qu’elle', 't’enfonce'],
#   ['t’enfonce', 'un'],
#   ['un', 'poisson'],
#   ['poisson', 'dans'],
#   ['dans', 'les'],
#   ['les', 'fesses']],
#  [['اضطراب', 'وانقطاع'],
#   ['وانقطاع', 'في'],
#   ['في', 'توزيع'],
#   ['توزيع', 'ماء'],
#   ['ماء', 'الشرب'],
#   ['الشرب', 'في'],
#   ['في', 'هذه'],
#   ['هذه', 'المناطق'],
#   ['المناطق', 'https://t.co/lof2ssHZpf']],
#  [['Un', 'montant'],
#   ['montant', 'total'],
#   ['total', 'de'],
#   ['de', 'près'],
#   ['près', 'de'],
#   ['de', '10,8'],
#   ['10,8', 'millions'],
#   ['millions', 'de'],
#   ['de', 'dollars'],
#   ['dollars', 'américains'],
#   ['américains', 'a'],
#   ['a', 'été'],
#   ['été', 'alloué'],
#   ['alloué', 'pour'],
#   ['pour', 'des'],
#   ['des', 'routes'],
#   ['routes', 'extérieures'],
#   ['extérieures', 'et'],
#   ['et', 'des'],
#   ['des', 'raccordements'],
#   ['raccordements', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable,'],
#   ['potable,', 'à'],
#   ['à', 'l’électricité'],
#   ['l’électricité', 'et'],
#   ['et', 'au'],
#   ['au', 'gaz,'],
#   ['gaz,', 'en'],
#   ['en', 'plus'],
#   ['plus', 'd’une'],
#   ['d’une', 'usine'],
#   ['usine', 'de'],
#   ['de', 'traitement'],
#   ['traitement', 'des'],
#   ['des', 'eaux'],
#   ['eaux', 'usées.'],
#   ['usées.', '#Tunisie'],
#   ['#Tunisie', '#Projet'],
#   ['#Projet', '#Investissement'],
#   ['#Investissement', 'https://t.co/q8Byvas98R']],
#  [['"A', 'l’échelle'],
#   ['l’échelle', 'national,'],
#   ['national,', 'le'],
#   ['le', 'taux'],
#   ['taux', 'de'],
#   ['de', 'desserte'],
#   ['desserte', 'en'],
#   ['en', '#eau'],
#   ['#eau', 'potable'],
#   ['potable', 'est'],
#   ['est', 'en'],
#   ['en', 'constante'],
#   ['constante', 'augmentation'],
#   ['augmentation', 'depuis'],
#   ['depuis', '20'],
#   ['20', 'ans.'],
#   ['ans.', 'Mais'],
#   ['Mais', 'aujourd’hui,'],
#   ['aujourd’hui,', 'selon'],
#   ['selon', 'les'],
#   ['les', 'chiffres...'],
#   ['chiffres...', 'https://t.co/lNyLQLyycn']],
#  [['"A', 'l’échelle'],
#   ['l’échelle', 'nationale,'],
#   ['nationale,', 'le'],
#   ['le', 'taux'],
#   ['taux', 'de'],
#   ['de', 'desserte'],
#   ['desserte', 'en'],
#   ['en', '#eau'],
#   ['#eau', 'potable'],
#   ['potable', 'est'],
#   ['est', 'en'],
#   ['en', 'constante'],
#   ['constante', 'augmentation'],
#   ['augmentation', 'depuis'],
#   ['depuis', '20'],
#   ['20', 'ans.'],
#   ['ans.', 'Mais'],
#   ['Mais', 'aujourd’hui,'],
#   ['aujourd’hui,', 'selon'],
#   ['selon', 'les'],
#   ['les', 'chiffres...'],
#   ['chiffres...', 'https://t.co/kODbQAwGFJ']],
#  [['RT', '@odilon236:'],
#   ['@odilon236:', '#CotedIvoire'],
#   ['#CotedIvoire', 'Traitement'],
#   ['Traitement', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', ':'],
#   [':', 'Bientôt'],
#   ['Bientôt', 'une'],
#   ['une', 'usine'],
#   ['usine', 'de'],
#   ['de', '108'],
#   ['108', 'milliards'],
#   ['milliards', 'de'],
#   ['de', 'FCFA'],
#   ['FCFA', 'à'],
#   ['à', 'Abidjan'],
#   ['Abidjan', 'https://t.co/8BNJKOC8vz'],
#   ['https://t.co/8BNJKOC8vz', '@abidja…']],
#  [['#CotedIvoire', 'Traitement'],
#   ['Traitement', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', ':'],
#   [':', 'Bientôt'],
#   ['Bientôt', 'une'],
#   ['une', 'usine'],
#   ['usine', 'de'],
#   ['de', '108'],
#   ['108', 'milliards'],
#   ['milliards', 'de'],
#   ['de', 'FCFA'],
#   ['FCFA', 'à'],
#   ['à', 'Abidjan'],
#   ['Abidjan', 'https://t.co/8BNJKOC8vz'],
#   ['https://t.co/8BNJKOC8vz', '@abidjantimes'],
#   ['@abidjantimes', '#Centrafrique']],
#  [['Près', 'de'],
#   ['de', '300.000'],
#   ['300.000', 'personnes'],
#   ['personnes', 'à'],
#   ['à', 'travers'],
#   ['travers', 'la'],
#   ['la', 'Tunisie'],
#   ['Tunisie', 'vivent'],
#   ['vivent', 'sans'],
#   ['sans', 'aucun'],
#   ['aucun', 'accès'],
#   ['accès', 'à'],
#   ['à', "l'eau"],
#   ["l'eau", 'potable.'],
#   ['potable.', 'Elles'],
#   ['Elles', 'sont'],
#   ['sont', 'obligées'],
#   ['obligées', 'de'],
#   ['de', 'recueillir'],
#   ['recueillir', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'de'],
#   ['de', 'pluie'],
#   ['pluie', 'ou'],
#   ['ou', 'dans'],
#   ['dans', 'les'],
#   ['les', 'sources.'],
#   ['sources.', 'Analyse'],
#   ['Analyse', 'en'],
#   ['en', 'chiffres'],
#   ['chiffres', "d'un"],
#   ["d'un", 'accès'],
#   ['accès', 'inégal'],
#   ['inégal', 'à'],
#   ['à', "l'eau."],
#   ["l'eau.", 'https://t.co/tLSGPAtoFJ'],
#   ['https://t.co/tLSGPAtoFJ', 'https://t.co/JLNPWA28nb']],
#  [['RT', '@TUNumerique:'],
#   ['@TUNumerique:', 'Tunisie'],
#   ['Tunisie', '–'],
#   ['–', 'La'],
#   ['La', 'SONEDE'],
#   ['SONEDE', 'annonce'],
#   ['annonce', 'une'],
#   ['une', 'méga'],
#   ['méga', 'coupure'],
#   ['coupure', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', 'sur'],
#   ['sur', 'le'],
#   ['le', 'grand'],
#   ['grand', 'Tunis'],
#   ['Tunis', 'https://t.co/h4l9pclVgQ']],
#  [['La', 'SONEDE'],
#   ['SONEDE', 'annonce'],
#   ['annonce', 'des'],
#   ['des', 'coupures'],
#   ['coupures', 'et'],
#   ['et', 'des'],
#   ['des', 'perturbations'],
#   ['perturbations', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'diverses'],
#   ['diverses', 'régions'],
#   ['régions', 'de'],
#   ['de', 'Tunis'],
#   ['Tunis', 'et'],
#   ['et', 'de'],
#   ['de', 'l’Ariana'],
#   ['l’Ariana', '–'],
#   ['–', 'Prenez'],
#   ['Prenez', 'donc'],
#   ['donc', 'vos'],
#   ['vos', 'précautions'],
#   ['précautions', 'dès'],
#   ['dès', 'ce'],
#   ['ce', 'soir'],
#   ['soir', 'https://t.co/ga3o4JNPiv']],
#  [['La', 'SONEDE'],
#   ['SONEDE', 'annonce'],
#   ['annonce', 'des'],
#   ['des', 'coupures'],
#   ['coupures', 'et'],
#   ['et', 'des'],
#   ['des', 'perturbations'],
#   ['perturbations', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'diverses'],
#   ['diverses', 'régions'],
#   ['régions', 'de'],
#   ['de', 'Tunis'],
#   ['Tunis', 'et'],
#   ['et', 'de'],
#   ['de', 'l’Ariana'],
#   ['l’Ariana', '|'],
#   ['|', 'Tunivisions'],
#   ['Tunivisions', 'https://t.co/sibjEIU5kD'],
#   ['https://t.co/sibjEIU5kD', 'via'],
#   ['via', '@Tunivisions']],
#  [['Tunisie', '–'],
#   ['–', 'La'],
#   ['La', 'SONEDE'],
#   ['SONEDE', 'annonce'],
#   ['annonce', 'une'],
#   ['une', 'méga'],
#   ['méga', 'coupure'],
#   ['coupure', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', 'sur'],
#   ['sur', 'le'],
#   ['le', 'grand'],
#   ['grand', 'Tunis'],
#   ['Tunis', 'https://t.co/h4l9pclVgQ']],
#  [['Tunis', 'et'],
#   ['et', 'Ariana'],
#   ['Ariana', ':'],
#   [':', 'perturbations'],
#   ['perturbations', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'https://t.co/CgVQSddmXk']],
#  [['Perturbation', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'à'],
#   ['à', 'Tunis'],
#   ['Tunis', 'et'],
#   ['et', 'à'],
#   ['à', "l'Ariana"],
#   ["l'Ariana", 'https://t.co/aOwPF599z4']],
#  [['Reprise', 'progressive'],
#   ['progressive', 'de'],
#   ['de', 'la'],
#   ['la', 'distribution'],
#   ['distribution', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'le'],
#   ['le', 'grand'],
#   ['grand', 'Tunis'],
#   ['Tunis', 'https://t.co/tSUvv3KJ3A'],
#   ['https://t.co/tSUvv3KJ3A', '#Tunisie']],
#  [['Après', '31'],
#   ['31', 'heures'],
#   ['heures', 'de'],
#   ['de', 'travail'],
#   ['travail', 'continu'],
#   ['continu', '...'],
#   ['...', 'https://t.co/DNYR94MOKI']],
#  [['La', 'Société'],
#   ['Société', 'Nationale'],
#   ['Nationale', "d'Exploitation"],
#   ["d'Exploitation", 'et'],
#   ['et', 'de'],
#   ['de', 'Distribution'],
#   ['Distribution', 'des'],
#   ['des', 'Eaux'],
#   ['Eaux', '(SONEDE)'],
#   ['(SONEDE)', 'annonce'],
#   ['annonce', 'la'],
#   ['la', 'fin'],
#   ['fin', 'des'],
#   ['des', 'travaux'],
#   ['travaux', 'de'],
#   ['de', 'réparation'],
#   ['réparation', 'du'],
#   ['du', 'Canal'],
#   ['Canal', 'principal'],
#   ['principal', 'de'],
#   ['de', 'distribution'],
#   ['distribution', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'pour'],
#   ['pour', 'Tunis'],
#   ['Tunis', 'et'],
#   ['et', 'l’Ariana'],
#   ['l’Ariana', 'https://t.co/Wplv4N4Huf']],
#  [['La', 'SONEDE'],
#   ['SONEDE', 'annonce'],
#   ['annonce', 'la'],
#   ['la', 'fin'],
#   ['fin', 'des'],
#   ['des', 'travaux'],
#   ['travaux', 'de'],
#   ['de', 'réparation'],
#   ['réparation', 'du'],
#   ['du', 'Canal'],
#   ['Canal', 'principal'],
#   ['principal', 'de'],
#   ['de', 'distribution'],
#   ['distribution', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'pour'],
#   ['pour', 'Tunis'],
#   ['Tunis', 'et'],
#   ['et', 'l’Ariana'],
#   ['l’Ariana', '|'],
#   ['|', 'Tunivisions'],
#   ['Tunivisions', 'https://t.co/sf8NAWXllz'],
#   ['https://t.co/sf8NAWXllz', 'via'],
#   ['via', '@Tunivisions']],
#  [['@NoahYannick', '@PierreChrist_'],
#   ['@PierreChrist_', '@BNPParibas'],
#   ['@BNPParibas', '@FeteleMur'],
#   ['@FeteleMur', '@WeAreTennisFR'],
#   ['@WeAreTennisFR', 'Bof...'],
#   ['Bof...', 'ya'],
#   ['ya', 'tjrs'],
#   ['tjrs', 'pas'],
#   ['pas', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'a'],
#   ['a', 'etoudi...'],
#   ['etoudi...', 'so'],
#   ['so', 'what?']],
#  [['الشرب', 'من'],
#   ['من', 'ماء'],
#   ['ماء', 'الصوناد'],
#   ['الصوناد', 'فريمون'],
#   ['فريمون', 'عندو'],
#   ['عندو', 'طعم'],
#   ['طعم', 'تاني'],
#   ['تاني', '😍'],
#   ['😍', 'هالنهارين!']],
#  [['L’eau', 'potable'],
#   ['potable', 'sera'],
#   ['sera', 'de'],
#   ['de', 'nouveau'],
#   ['nouveau', 'disponible'],
#   ['disponible', 'lorsque'],
#   ['lorsque', 'les'],
#   ['les', 'réservoirs'],
#   ['réservoirs', 'de'],
#   ['de', 'distribution'],
#   ['distribution', 'seront'],
#   ['seront', 'à'],
#   ['à', 'nouveau'],
#   ['nouveau', 'remplis.'],
#   ['remplis.', '#Actualité'],
#   ['#Actualité', '#Tunis'],
#   ['#Tunis', 'https://t.co/KlUV8CygW1']],
#  [['Tunisie:', 'Perturbation'],
#   ['Perturbation', 'de'],
#   ['de', "l'approvisionnement"],
#   ["l'approvisionnement", 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'cités'],
#   ['cités', 'Ettadhamen'],
#   ['Ettadhamen', 'et'],
#   ['et', 'Ettahrir'],
#   ['Ettahrir', 'https://t.co/MnzL8xpvYX']],
#  [['La', 'reprise'],
#   ['reprise', 'sera'],
#   ['sera', 'assurée,'],
#   ['assurée,', 'progressivement,'],
#   ['progressivement,', 'mercredi'],
#   ['mercredi', '20'],
#   ['20', 'mars'],
#   ['mars', '2019...'],
#   ['2019...', 'https://t.co/9Ck6qORyZO']],
#  [['#SONEDE', 'a'],
#   ['a', 'annoncé'],
#   ['annoncé', 'lundi,'],
#   ['lundi,', 'une'],
#   ['une', 'coupure'],
#   ['coupure', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'prévue'],
#   ['prévue', 'mardi'],
#   ['mardi', '19'],
#   ['19', 'mars'],
#   ['mars', '2019,'],
#   ['2019,', 'à'],
#   ['à', 'partir'],
#   ['partir', 'de'],
#   ['de', '08H'],
#   ['08H', 'du'],
#   ['du', 'matin'],
#   ['matin', 'dans'],
#   ['dans', 'la'],
#   ['la', 'ville'],
#   ['ville', 'de'],
#   ['de', 'Djebel'],
#   ['Djebel', 'El'],
#   ['El', 'Oust.'],
#   ['Oust.', '#Zaghouan'],
#   ['#Zaghouan', '#Tunisie'],
#   ['#Tunisie', 'https://t.co/WcZ7rDkahQ'],
#   ['https://t.co/WcZ7rDkahQ', 'https://t.co/MgenPrbsMR']],
#  [['Coupure', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'à'],
#   ['à', 'Djebel'],
#   ['Djebel', 'El'],
#   ['El', 'Oust'],
#   ['Oust', 'https://t.co/hAEPtcJQY7']],
#  [['Passage', 'au'],
#   ['au', 'Vote'],
#   ['Vote', 'sur'],
#   ['sur', 'le'],
#   ['le', 'Projet'],
#   ['Projet', 'de'],
#   ['de', 'loi'],
#   ['loi', 'N°12/2019'],
#   ['N°12/2019', 'portant'],
#   ['portant', 'approbation'],
#   ['approbation', 'de'],
#   ['de', 'la'],
#   ['la', 'convention'],
#   ['convention', 'de'],
#   ['de', 'prêt'],
#   ['prêt', 'entre'],
#   ['entre', 'le'],
#   ['le', 'Fonds'],
#   ['Fonds', 'Saoudien'],
#   ['Saoudien', 'de'],
#   ['de', 'Développement'],
#   ['Développement', 'et'],
#   ['et', 'la'],
#   ['la', 'Tunisie'],
#   ['Tunisie', 'pour'],
#   ['pour', 'le'],
#   ['le', 'financement'],
#   ['financement', 'du'],
#   ['du', 'projet'],
#   ['projet', 'd’amélioration'],
#   ['d’amélioration', 'de'],
#   ['de', 'la'],
#   ['la', 'desserte'],
#   ['desserte', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'en'],
#   ['en', 'milieu'],
#   ['milieu', 'rural'],
#   ['rural', 'dans'],
#   ['dans', 'le'],
#   ['le', 'gouvernorat'],
#   ['gouvernorat', 'de'],
#   ['de', 'Bizerte'],
#   ['Bizerte', '#TNARP']],
#  [['A', "l'ordre"],
#   ["l'ordre", 'du'],
#   ['du', 'jour:'],
#   ['jour:', "L'examen"],
#   ["L'examen", 'du'],
#   ['du', 'projet'],
#   ['projet', 'de'],
#   ['de', 'loi'],
#   ['loi', 'portant'],
#   ['portant', 'approbation'],
#   ['approbation', 'de'],
#   ['de', 'la'],
#   ['la', 'convention'],
#   ['convention', 'de'],
#   ['de', 'prêt'],
#   ['prêt', 'pour'],
#   ['pour', 'le'],
#   ['le', 'financement'],
#   ['financement', 'du'],
#   ['du', 'projet'],
#   ['projet', '«'],
#   ['«', 'd’amélioration'],
#   ['d’amélioration', 'de'],
#   ['de', 'la'],
#   ['la', 'desserte'],
#   ['desserte', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'en'],
#   ['en', 'milieu'],
#   ['milieu', 'rural'],
#   ['rural', 'dans'],
#   ['dans', 'le'],
#   ['le', 'gouvernorat'],
#   ['gouvernorat', 'de'],
#   ['de', 'Bizerte'],
#   ['Bizerte', '»']],
#  [['#CapVert,', 'Le'],
#   ['Le', 'prix'],
#   ['prix', 'du'],
#   ['du', 'mètre'],
#   ['mètre', 'cube'],
#   ['cube', "d'eau"],
#   ["d'eau", 'fixé'],
#   ['fixé', 'à'],
#   ['à', '0,122'],
#   ['0,122', 'USD,'],
#   ['USD,', 'soit'],
#   ['soit', '70.69'],
#   ['70.69', 'XAF.'],
#   ['XAF.', 'Ceci'],
#   ['Ceci', 'est'],
#   ['est', 'une'],
#   ['une', 'initiative'],
#   ['initiative', 'à'],
#   ['à', 'féliciter'],
#   ['féliciter', 'car'],
#   ['car', 'elle'],
#   ['elle', 'permet'],
#   ['permet', 'à'],
#   ['à', 'tous'],
#   ['tous', 'les'],
#   ['les', 'ménages'],
#   ['ménages', 'de'],
#   ['de', 'se'],
#   ['se', 'procurer'],
#   ['procurer', 'une'],
#   ['une', 'eau'],
#   ['eau', 'potable.'],
#   ['potable.', 'Pour'],
#   ['Pour', 'quoi'],
#   ['quoi', 'au'],
#   ['au', '#Cameroun'],
#   ['#Cameroun', "l'eau"],
#   ["l'eau", 'est'],
#   ['est', 'aussi'],
#   ['aussi', 'cher?'],
#   ['cher?', 'Le'],
#   ['Le', 'mètre'],
#   ['mètre', 'cube'],
#   ['cube', 'coûte'],
#   ['coûte', '364'],
#   ['364', 'XAF.'],
#   ['XAF.', '#Water4All'],
#   ['#Water4All', '📷(AFP)'],
#   ['📷(AFP)', 'https://t.co/buMIgg00NN']],
#  [['Plus', 'de'],
#   ['de', '800'],
#   ['800', 'millions'],
#   ['millions', 'd’humains'],
#   ['d’humains', 'privés'],
#   ['privés', 'd’eau'],
#   ['d’eau', 'potable:'],
#   ['potable:', 'Les'],
#   ['Les', 'Nations'],
#   ['Nations', 'unies'],
#   ['unies', 'dressent'],
#   ['dressent', 'un'],
#   ['un', 'tableau'],
#   ['tableau', 'alarmant'],
#   ['alarmant', 'de'],
#   ['de', 'l’accès'],
#   ['l’accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'son'],
#   ['son', 'rapport'],
#   ['rapport', '2019.'],
#   ['2019.', 'En'],
#   ['En', '2015,'],
#   ['2015,', 'six'],
#   ['six', 'humains'],
#   ['humains', 'sur'],
#   ['sur', 'dix'],
#   ['dix', 'ne'],
#   ['ne', 'disposaient'],
#   ['disposaient', 'pas'],
#   ['pas', 'de'],
#   ['de', 'toilettes'],
#   ['toilettes', 'ou'],
#   ['ou', 'équivalent.'],
#   ['équivalent.', 'https://t.co/S0Tqc5UbHC'],
#   ['https://t.co/S0Tqc5UbHC', 'https://t.co/mTfRnwKYCH']],
#  [['Plus', 'de'],
#   ['de', 'deux'],
#   ['deux', 'milliards'],
#   ['milliards', 'de'],
#   ['de', 'personnes'],
#   ['personnes', 'sans'],
#   ['sans', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'le'],
#   ['le', 'monde'],
#   ['monde', ':'],
#   [':', 'le'],
#   ['le', 'constat'],
#   ['constat', 'alarmant'],
#   ['alarmant', 'de'],
#   ['de', "l'ONU"],
#   ["l'ONU", 'via'],
#   ['via', '@franceinter'],
#   ['@franceinter', 'https://t.co/BjdU1IjFy5']],
#  [['Cameroun:', 'environ'],
#   ['environ', '9'],
#   ['9', 'millions'],
#   ['millions', 'de'],
#   ['de', 'personnes'],
#   ['personnes', 'n’ont'],
#   ['n’ont', 'pas'],
#   ['pas', 'accès'],
#   ['accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable.'],
#   ['potable.', 'Lisez'],
#   ['Lisez', "l'article"],
#   ["l'article", 'complet'],
#   ['complet', 'en'],
#   ['en', 'cliquant'],
#   ['cliquant', 'sur'],
#   ['sur', 'le'],
#   ['le', 'lien.#JourneeMondialeDelEa'],
#   ['lien.#JourneeMondialeDelEa', '#WorldWaterDay'],
#   ['#WorldWaterDay', 'https://t.co/CUQ6NetDlD'],
#   ['https://t.co/CUQ6NetDlD', 'via'],
#   ['via', '@JDC_Fr']],
#  [['#SVQ', '2,1'],
#   ['2,1', 'milliards'],
#   ['milliards', 'de'],
#   ['de', 'personnes'],
#   ['personnes', 'vivent'],
#   ['vivent', 'sans'],
#   ['sans', 'accès'],
#   ['accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'chez'],
#   ['chez', 'eux?'],
#   ['eux?', 'En'],
#   ['En', 'cette'],
#   ['cette', '#JournéeMondialeDeLeau,'],
#   ['#JournéeMondialeDeLeau,', 'joignez-vous'],
#   ['joignez-vous', 'au'],
#   ['au', 'Canada'],
#   ['Canada', '🇨🇦'],
#   ['🇨🇦', 'et'],
#   ['et', 'soutenez'],
#   ['soutenez', '#DeLeauPourTous.'],
#   ['#DeLeauPourTous.', 'Faisons'],
#   ['Faisons', 'en'],
#   ['en', 'sorte'],
#   ['sorte', 'que'],
#   ['que', 'PERSONNE'],
#   ['PERSONNE', 'ne'],
#   ['ne', 'soit'],
#   ['soit', 'laissé'],
#   ['laissé', 'pour'],
#   ['pour', 'compte.'],
#   ['compte.', '#ODD6'],
#   ['#ODD6', 'https://t.co/eGbkYFGG7A']],
#  [["Aujourd'hui,", 'journée'],
#   ['journée', 'internationale'],
#   ['internationale', 'de'],
#   ['de', "l'eau,"],
#   ["l'eau,", 'plus'],
#   ['plus', 'de'],
#   ['de', '2'],
#   ['2', 'milliards'],
#   ['milliards', 'de'],
#   ['de', 'personnes'],
#   ['personnes', "n'ont"],
#   ["n'ont", 'pas'],
#   ['pas', 'accès'],
#   ['accès', 'à'],
#   ['à', "l'eau"],
#   ["l'eau", 'potable,'],
#   ['potable,', 'surtout'],
#   ['surtout', 'en'],
#   ['en', 'Afrique.'],
#   ['Afrique.', "L'eau,"],
#   ["L'eau,", "c'est"],
#   ["c'est", '60%'],
#   ['60%', 'du'],
#   ['du', 'poids'],
#   ['poids', 'du'],
#   ['du', 'corps'],
#   ['corps', 'et'],
#   ['et', 'chacun'],
#   ['chacun', 'a'],
#   ['a', 'besoin'],
#   ['besoin', 'de'],
#   ['de', '1,5'],
#   ['1,5', 'l'],
#   ['l', "d'eau/jour."],
#   ["d'eau/jour.", "L'eau"],
#   ["L'eau", "c'est"],
#   ["c'est", 'la'],
#   ['la', 'vie'],
#   ['vie', 'et'],
#   ['et', "c'est"],
#   ["c'est", 'un'],
#   ['un', 'droit'],
#   ['droit', 'pour'],
#   ['pour', 'tous'],
#   ['tous', '!']],
#  [['Le', 'manque'],
#   ['manque', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'tue'],
#   ['tue', '3'],
#   ['3', 'fois'],
#   ['fois', 'plus'],
#   ['plus', "d'enfants"],
#   ["d'enfants", 'que'],
#   ['que', 'la'],
#   ['la', 'violence'],
#   ['violence', 'dans'],
#   ['dans', 'les'],
#   ['les', 'pays'],
#   ['pays', 'en'],
#   ['en', 'conflit'],
#   ['conflit', 'https://t.co/PDjrr7P4gZ'],
#   ['https://t.co/PDjrr7P4gZ', 'via'],
#   ['via', '@rtbfinfo']],
#  [['Alerte', 'aux'],
#   ['aux', 'pesticides'],
#   ['pesticides', 'dans'],
#   ['dans', "l'eau"],
#   ["l'eau", 'potable:'],
#   ['potable:', 'UFC-Que'],
#   ['UFC-Que', 'Choisir'],
#   ['Choisir', 'veut'],
#   ['veut', 'faire'],
#   ['faire', 'payer'],
#   ['payer', 'les'],
#   ['les', 'agriculteurs'],
#   ['agriculteurs', 'pour'],
#   ['pour', 'la'],
#   ['la', 'dépollution'],
#   ['dépollution', '!'],
#   ['!', 'https://t.co/ilwtSOmrWI']],
#  [['@unknownbotasky', '@jyms95'],
#   ['@jyms95', '@PaulinePaccard'],
#   ['@PaulinePaccard', '@France24_fr'],
#   ['@France24_fr', 'êtes'],
#   ['êtes', 'vous'],
#   ['vous', 'sûr'],
#   ['sûr', "qu'il"],
#   ["qu'il", "s'agit"],
#   ["s'agit", 'bien'],
#   ['bien', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', '??']],
#  [['Les', 'travaux'],
#   ['travaux', 'de'],
#   ['de', 'Keur'],
#   ['Keur', 'Momar'],
#   ['Momar', 'Sarr'],
#   ['Sarr', 'réalisés'],
#   ['réalisés', 'à'],
#   ['à', '40%'],
#   ['40%', 'https://t.co/ipDMP8N2Lf']],
#  [['RT', '@BsiLiAdeL:'],
#   ['@BsiLiAdeL:', 'Je'],
#   ['Je', 'suis'],
#   ['suis', 'admiratif'],
#   ['admiratif', 'de'],
#   ['de', 'ce'],
#   ['ce', 'que'],
#   ['que', 'je'],
#   ['je', 'regarde'],
#   ['regarde', 'now:'],
#   ['now:', 'le'],
#   ['le', 'Conseil'],
#   ['Conseil', 'Municipal'],
#   ['Municipal', 'de'],
#   ['de', 'Tripoli'],
#   ['Tripoli', 'qui'],
# ...
#   ['RÉ-ÉQUILIBRANTE', ':'],
#   [':', 'Calmante,'],
#   ['Calmante,', 'Adoucissante'],
#   ['Adoucissante', 'et'],
#   ['et', 'Apaisante'],
#   ['Apaisante', '🤩🤩'],
#   ['🤩🤩', '.'],
#   ['.', 'DISPONIBLE'],
#   ['DISPONIBLE', 'IMMÉDIATEMENT…'],
#   ['IMMÉDIATEMENT…', 'https://t.co/218dAAG8tU']],
#  [['Le', 'volume'],
#   ['volume', 'des'],
#   ['des', 'investissements'],
#   ['investissements', 'de'],
#   ['de', 'la'],
#   ['la', 'BAD'],
#   ['BAD', 'en'],
#   ['en', '#Tunisie,'],
#   ['#Tunisie,', 'a'],
#   ['a', 'atteint'],
#   ['atteint', '1,4'],
#   ['1,4', 'milliard'],
#   ['milliard', 'de'],
#   ['de', 'dollars'],
#   ['dollars', '(près'],
#   ['(près', 'de'],
#   ['de', '4,2'],
#   ['4,2', 'milliards'],
#   ['milliards', 'de'],
#   ['de', 'dinars),'],
#   ['dinars),', 'dans'],
#   ['dans', 'divers'],
#   ['divers', 'domaines'],
#   ['domaines', 'tels'],
#   ['tels', 'que'],
#   ['que', 'l’énergie,'],
#   ['l’énergie,', 'le'],
#   ['le', 'transport,'],
#   ['transport,', 'les'],
#   ['les', 'télécommunications,'],
#   ['télécommunications,', 'l’eau,'],
#   ['l’eau,', 'la'],
#   ['la', 'technologie…']],
#  [['#Phytodigest', '#Gélules'],
#   ['#Gélules', 'aide'],
#   ['aide', 'à'],
#   ['à', 'retenir'],
#   ['retenir', 'l’#eau'],
#   ['l’#eau', 'à'],
#   ['à', 'l’intérieur'],
#   ['l’intérieur', 'de'],
#   ['de', 'l’#intestin'],
#   ['l’#intestin', 'ce'],
#   ['ce', 'qui'],
#   ['qui', 'augmente'],
#   ['augmente', 'le'],
#   ['le', '#teneur'],
#   ['#teneur', 'des'],
#   ['des', '#selles'],
#   ['#selles', 'en'],
#   ['en', 'eau'],
#   ['eau', 'au'],
#   ['au', 'niveau'],
#   ['niveau', 'du'],
#   ['du', 'gros'],
#   ['gros', '#intestin.'],
#   ['#intestin.', 'De'],
#   ['De', 'plus'],
#   ['plus', 'il'],
#   ['il', 'forme'],
#   ['forme', 'un'],
#   ['un', 'gel'],
#   ['gel', 'et'],
#   ['et', 'facilite'],
#   ['facilite', 'le'],
#   ['le', 'transit'],
#   ['transit', 'au'],
#   ['au', 'niveau'],
#   ['niveau', 'de'],
#   ['de', 'l’#estomac'],
#   ['l’#estomac', 'et'],
#   ['et', 'de'],
#   ['de', 'l’#intestin'],
#   ['l’#intestin', 'grêle.'],
#   ['grêle.', 'https://t.co/rpCgdMbgSg']],
#  [['@myIifeisrosy', 'wtf'],
#   ['wtf', 'il'],
#   ['il', 'aurait'],
#   ['aurait', 'du'],
#   ['du', 'mettre'],
#   ['mettre', 'la'],
#   ['la', 'vodka'],
#   ['vodka', 'dans'],
#   ['dans', '1bouteille'],
#   ['1bouteille', "d'eau"]],
#  [['Alimentée', 'par'],
#   ['par', 'des'],
#   ['des', 'déchets'],
#   ['déchets', 'végétaux,'],
#   ['végétaux,', 'ce'],
#   ['ce', 'conteneur'],
#   ['conteneur', 'est'],
#   ['est', 'capable'],
#   ['capable', 'de'],
#   ['de', 'transformer'],
#   ['transformer', "l'humidité"],
#   ["l'humidité", 'de'],
#   ['de', "l'air"],
#   ["l'air", 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'et'],
#   ['et', 'fabrique'],
#   ['fabrique', '2000'],
#   ['2000', 'litres'],
#   ['litres', "d'eau"],
#   ["d'eau", 'par'],
#   ['par', 'jour.'],
#   ['jour.', 'Remarquable'],
#   ['Remarquable', '!'],
#   ['!', 'https://t.co/TcAssExlVq']],
#  [['#WaterlessTripoli.', 'Tripoli'],
#   ['Tripoli', 'sans'],
#   ['sans', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'LNA'],
#   ['LNA', 'COUPE'],
#   ['COUPE', 'L'],
#   ['L', 'EZU'],
#   ['EZU', 'SUR'],
#   ['SUR', 'TRIPOLI']],
#  [['Aspirant', "l'air"],
#   ["l'air", 'chaud,'],
#   ['chaud,', 'ce'],
#   ['ce', 'conteneur'],
#   ['conteneur', 'produit'],
#   ['produit', '2000'],
#   ['2000', 'litres'],
#   ['litres', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'par'],
#   ['par', 'jour.'],
#   ['jour.', '(VIDÉO)'],
#   ['(VIDÉO)', 'https://t.co/VXhfYbTKBB']],
#  [['Ridha', 'Chalghoum'],
#   ['Chalghoum', 'promet'],
#   ['promet', 'la'],
#   ['la', 'mobilisation'],
#   ['mobilisation', 'des'],
#   ['des', 'financements'],
#   ['financements', 'en'],
#   ['en', 'faveur'],
#   ['faveur', 'des'],
#   ['des', 'projets'],
#   ['projets', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'bloqués'],
#   ['bloqués', 'à'],
#   ['à', 'Sfax'],
#   ['Sfax', 'https://t.co/fivJyZzgkY']],
#  [['Coupure', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'les'],
#   ['les', 'gouvernorats'],
#   ['gouvernorats', 'de'],
#   ['de', 'la'],
#   ['la', '#Manouba'],
#   ['#Manouba', 'et'],
#   ['et', '#Béja:'],
#   ['#Béja:', 'https://t.co/W0dUPP3AGH'],
#   ['https://t.co/W0dUPP3AGH', 'via'],
#   ['via', '@espacemanager']],
#  [['Pour', 'rapporter'],
#   ['rapporter', 'de'],
#   ['de', "l'#eau"],
#   ["l'#eau", 'potable'],
#   ['potable', 'à'],
#   ['à', 'leur'],
#   ['leur', 'famille,'],
#   ['famille,', 'ces'],
#   ['ces', 'femmes'],
#   ['femmes', 'indiennes'],
#   ['indiennes', 'risquent'],
#   ['risquent', 'leur'],
#   ['leur', 'vie'],
#   ['vie', 'chaque'],
#   ['chaque', 'jour'],
#   ['jour', 'en'],
#   ['en', 'descendant'],
#   ['descendant', 'en'],
#   ['en', 'rappel'],
#   ['rappel', 'dans'],
#   ['dans', 'un'],
#   ['un', 'puits'],
#   ['puits', 'de'],
#   ['de', '18'],
#   ['18', 'mètres'],
#   ['mètres', 'de'],
#   ['de', 'profondeur.'],
#   ['profondeur.', 'En'],
#   ['En', '#Inde,'],
#   ['#Inde,', '75'],
#   ['75', '%'],
#   ['%', 'des'],
#   ['des', 'foyers'],
#   ['foyers', "n'ont"],
#   ["n'ont", 'pas'],
#   ['pas', 'accès'],
#   ['accès', 'à'],
#   ['à', "l'eau"],
#   ["l'eau", 'potable.'],
#   ['potable.', 'https://t.co/vDebFB6Bdz'],
#   ['https://t.co/vDebFB6Bdz', '#India'],
#   ['#India', '#HumanRight'],
#   ['#HumanRight', 'to'],
#   ['to', '#Water']],
#  [['RT', '@F7hmayda:'],
#   ['@F7hmayda:', '@alshabab_visca'],
#   ['@alshabab_visca', 'والله'],
#   ['والله', 'رغم'],
#   ['رغم', 'سوء'],
#   ['سوء', 'الحالة'],
#   ['الحالة', 'بالحي'],
#   ['بالحي', 'ونقص'],
#   ['ونقص', 'الماء'],
#   ['الماء', 'الصالح'],
#   ['الصالح', 'للشراب']],
#  [['@alshabab_visca', 'والله'],
#   ['والله', 'رغم'],
#   ['رغم', 'سوء'],
#   ['سوء', 'الحالة'],
#   ['الحالة', 'بالحي'],
#   ['بالحي', 'ونقص'],
#   ['ونقص', 'الماء'],
#   ['الماء', 'الصالح'],
#   ['الصالح', 'للشراب']],
#  [['الحق', 'في'],
#   ['في', 'الماء'],
#   ['الماء', 'الصالح'],
#   ['الصالح', 'للشراب'],
#   ['للشراب', 'https://t.co/8NByB34iQi']],
#  [['#Tunisie', 'Perturbations'],
#   ['Perturbations', 'et'],
#   ['et', 'coupures'],
#   ['coupures', 'de'],
#   ['de', "l'eau"],
#   ["l'eau", 'potable'],
#   ['potable', 'aux'],
#   ['aux', 'cités'],
#   ['cités', 'Ettadhamen'],
#   ['Ettadhamen', 'et'],
#   ['et', 'Douar'],
#   ['Douar', 'Hicher,'],
#   ['Hicher,', 'la'],
#   ['la', 'reprise'],
#   ['reprise', 'est'],
#   ['est', 'prévue'],
#   ['prévue', 'ce'],
#   ['ce', 'soir,'],
#   ['soir,', 'selon'],
#   ['selon', 'la'],
#   ['la', '#SONEDE']],
#  [['Jendouba', ':'],
#   [':', '70%'],
#   ['70%', 'des'],
#   ['des', 'projets'],
#   ['projets', 'd’approvisionnement'],
#   ['d’approvisionnement', 'des'],
#   ['des', 'zones'],
#   ['zones', 'rurales'],
#   ['rurales', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'seront'],
#   ['seront', 'entamés'],
#   ['entamés', 'en'],
#   ['en', '2019'],
#   ['2019', 'https://t.co/EaDNDdhOdl']],
#  [['Hamdullah,', 'on'],
#   ['on', 'ne'],
#   ['ne', 'peut'],
#   ['peut', 'que'],
#   ['que', "s'en"],
#   ["s'en", 'réjouir!'],
#   ['réjouir!', 'https://t.co/816XrdNDqg']],
#  [['Et', 'puis'],
#   ['puis', 'un'],
#   ['un', 'jour'],
#   ['jour', 'de'],
#   ['de', 'ramadan'],
#   ['ramadan', '14h'],
#   ['14h', 'et'],
#   ['et', '27’c'],
#   ['27’c', 'a'],
#   ['a', 'l’ombre'],
#   ['l’ombre', 'et'],
#   ['et', 'y’a'],
#   ['y’a', '#Sonede'],
#   ['#Sonede', 'qui'],
#   ['qui', 'nous'],
#   ['nous', 'programme'],
#   ['programme', 'a'],
#   ['a', '#Mourouj'],
#   ['#Mourouj', 'une'],
#   ['une', 'coupure'],
#   ['coupure', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'nous'],
#   ['nous', 'laissant'],
#   ['laissant', 'comme'],
#   ['comme', 'toujours'],
#   ['toujours', 'seul'],
#   ['seul', 'face'],
#   ['face', 'à'],
#   ['à', 'notre'],
#   ['notre', 'destin'],
#   ['destin', 'sans'],
#   ['sans', 'préavis'],
#   ['préavis', 'ni'],
#   ['ni', 'rien'],
#   ['rien', 'du'],
#   ['du', 'tout'],
#   ['tout', '#Tunisie']],
#  [['@YoCh_Official', 'Si'],
#   ['Si', 'Vs'],
#   ['Vs', 'pouvez'],
#   ['pouvez', 'me'],
#   ['me', 'répondre'],
#   ['répondre', 'sur'],
#   ['sur', 'mon'],
#   ['mon', 'projet'],
#   ['projet', 'de'],
#   ['de', 'dessalement'],
#   ['dessalement', 'de'],
#   ['de', 'Mahdia'],
#   ['Mahdia', 'basé'],
#   ['basé', 'sur'],
#   ['sur', '100%d'],
#   ['100%d', 'énergie'],
#   ['énergie', 'renouvelable'],
#   ['renouvelable', 'pour'],
#   ['pour', 'produire'],
#   ['produire', 'de'],
#   ['de', 'l'],
#   ['l', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'pour'],
#   ['pour', 'une'],
#   ['une', 'population'],
#   ['population', 'de'],
#   ['de', '500.000'],
#   ['500.000', 'habitants'],
#   ['habitants', '...je'],
#   ['...je', 'suis'],
#   ['suis', 'Ds'],
#   ['Ds', 'la'],
#   ['la', 'liste'],
#   ['liste', 'd'],
#   ['d', 'attente'],
#   ['attente', 'du'],
#   ['du', 'gouvernement'],
#   ['gouvernement', 'depuis'],
#   ['depuis', '2016...plutôt'],
#   ['2016...plutôt', 'Ds'],
#   ['Ds', 'la'],
#   ['la', 'liste'],
#   ['liste', 'de'],
#   ['de', 'blocage.'],
#   ['blocage.', '..'],
#   ['..', 'https://t.co/oFBBXzhOY8']],
#  [['Perturbations', 'et'],
#   ['et', 'coupures'],
#   ['coupures', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', 'd’eau'],
#   ['d’eau', 'potable'],
#   ['potable', 'à'],
#   ['à', 'Menzel'],
#   ['Menzel', 'Bouzayane'],
#   ['Bouzayane', 'https://t.co/bKP48ooI6u'],
#   ['https://t.co/bKP48ooI6u', 'https://t.co/ZNfUrd4v9N']],
#  [['Tunisie:', 'Perturbations'],
#   ['Perturbations', 'dans'],
#   ['dans', 'la'],
#   ['la', 'distribution'],
#   ['distribution', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'à'],
#   ['à', 'Menzel'],
#   ['Menzel', 'Bouzayane'],
#   ['Bouzayane', 'https://t.co/uXeRs3O5eH']],
#  [['RT', '@alisnoussi1:'],
#   ['@alisnoussi1:', '@YoCh_Official'],
#   ['@YoCh_Official', 'Si'],
#   ['Si', 'Vs'],
#   ['Vs', 'pouvez'],
#   ['pouvez', 'me'],
#   ['me', 'répondre'],
#   ['répondre', 'sur'],
#   ['sur', 'mon'],
#   ['mon', 'projet'],
#   ['projet', 'de'],
#   ['de', 'dessalement'],
#   ['dessalement', 'de'],
#   ['de', 'Mahdia'],
#   ['Mahdia', 'basé'],
#   ['basé', 'sur'],
#   ['sur', '100%d'],
#   ['100%d', 'énergie'],
#   ['énergie', 'renouvelable'],
#   ['renouvelable', 'pour'],
#   ['pour', 'p…']],
#  [['En', '#Afrique'],
#   ['#Afrique', 'subsaharienne,'],
#   ['subsaharienne,', 'seulement'],
#   ['seulement', '24%'],
#   ['24%', 'de'],
#   ['de', 'la'],
#   ['la', 'population'],
#   ['population', 'a'],
#   ['a', 'accès'],
#   ['accès', 'à'],
#   ['à', 'une'],
#   ['une', 'source'],
#   ['source', 'sûre'],
#   ['sûre', 'd’#eau'],
#   ['d’#eau', 'potable'],
#   ['potable', 'et'],
#   ['et', 'les'],
#   ['les', 'installations'],
#   ['installations', '#sanitaires'],
#   ['#sanitaires', 'de'],
#   ['de', 'base'],
#   ['base', '–non'],
#   ['–non', 'partagées'],
#   ['partagées', 'avec'],
#   ['avec', 'd’autres'],
#   ['d’autres', 'foyers'],
#   ['foyers', '-'],
#   ['-', 'sont'],
#   ['sont', 'réservées'],
#   ['réservées', 'à'],
#   ['à', '28%'],
#   ['28%', 'de'],
#   ['de', 'la'],
#   ['la', 'population.'],
#   ['population.', 'L’accès'],
#   ['L’accès', 'à'],
#   ['à', 'l’#eau'],
#   ['l’#eau', 'et'],
#   ['et', 'à'],
#   ['à', "l'assainissement"],
#   ["l'assainissement", 'est'],
#   ['est', 'un'],
#   ['un', '#DroitHumain!'],
#   ['#DroitHumain!', '@UN'],
#   ['@UN', 'https://t.co/FZIgcFftiG']],
#  [['RT', '@ACA_WeAdvocate:'],
#   ['@ACA_WeAdvocate:', 'L’accès'],
#   ['L’accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'et'],
#   ['et', 'à'],
#   ['à', 'l’assainissement'],
#   ['l’assainissement', 'est'],
#   ['est', 'reconnu'],
#   ['reconnu', 'comme'],
#   ['comme', 'un'],
#   ['un', 'Droit'],
#   ['Droit', 'de'],
#   ['de', 'l’homme'],
#   ['l’homme', 'depuis'],
#   ['depuis', '2010,'],
#   ['2010,', 'mais'],
#   ['mais', 'près'],
#   ['près', 'de'],
#   ['de', '3,5'],
#   ['3,5', 'milli…']],
#  [['RT', '@ACA_WeAdvocate:'],
#   ['@ACA_WeAdvocate:', 'L’accès'],
#   ['L’accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'et'],
#   ['et', 'à'],
#   ['à', 'l’assainissement'],
#   ['l’assainissement', 'est'],
#   ['est', 'reconnu'],
#   ['reconnu', 'comme'],
#   ['comme', 'un'],
#   ['un', 'Droit'],
#   ['Droit', 'de'],
#   ['de', 'l’homme'],
#   ['l’homme', 'depuis'],
#   ['depuis', '2010,'],
#   ['2010,', 'mais'],
#   ['mais', 'près'],
#   ['près', 'de'],
#   ['de', '3,5'],
#   ['3,5', 'milli…']],
#  [['RT', '@ACA_WeAdvocate:'],
#   ['@ACA_WeAdvocate:', 'L’accès'],
#   ['L’accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'et'],
#   ['et', 'à'],
#   ['à', 'l’assainissement'],
#   ['l’assainissement', 'est'],
#   ['est', 'reconnu'],
#   ['reconnu', 'comme'],
#   ['comme', 'un'],
#   ['un', 'Droit'],
#   ['Droit', 'de'],
#   ['de', 'l’homme'],
#   ['l’homme', 'depuis'],
#   ['depuis', '2010,'],
#   ['2010,', 'mais'],
#   ['mais', 'près'],
#   ['près', 'de'],
#   ['de', '3,5'],
#   ['3,5', 'milli…']],
#  [['RT', '@ACA_WeAdvocate:'],
#   ['@ACA_WeAdvocate:', 'L’accès'],
#   ['L’accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'et'],
#   ['et', 'à'],
#   ['à', 'l’assainissement'],
#   ['l’assainissement', 'est'],
#   ['est', 'reconnu'],
#   ['reconnu', 'comme'],
#   ['comme', 'un'],
#   ['un', 'Droit'],
#   ['Droit', 'de'],
#   ['de', 'l’homme'],
#   ['l’homme', 'depuis'],
#   ['depuis', '2010,'],
#   ['2010,', 'mais'],
#   ['mais', 'près'],
#   ['près', 'de'],
#   ['de', '3,5'],
#   ['3,5', 'milli…']],
#  [['L’accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'et'],
#   ['et', 'à'],
#   ['à', 'l’assainissement'],
#   ['l’assainissement', 'est'],
#   ['est', 'reconnu'],
#   ['reconnu', 'comme'],
#   ['comme', 'un'],
#   ['un', 'Droit'],
#   ['Droit', 'de'],
#   ['de', 'l’homme'],
#   ['l’homme', 'depuis'],
#   ['depuis', '2010,'],
#   ['2010,', 'mais'],
#   ['mais', 'près'],
#   ['près', 'de'],
#   ['de', '3,5'],
#   ['3,5', 'milliards'],
#   ['milliards', 'd’êtres'],
#   ['d’êtres', 'humains'],
#   ['humains', 'n’ont,'],
#   ['n’ont,', 'encore'],
#   ['encore', 'aujourd’hui,'],
#   ['aujourd’hui,', 'd’autre'],
#   ['d’autre', 'choix'],
#   ['choix', 'que'],
#   ['que', 'de'],
#   ['de', 'boire'],
#   ['boire', 'une'],
#   ['une', 'eau'],
#   ['eau', 'dangereuse'],
#   ['dangereuse', 'pour'],
#   ['pour', 'leur'],
#   ['leur', 'santé.'],
#   ['santé.', '2,4'],
#   ['2,4', 'milliards'],
#   ['milliards', 'ne'],
#   ['ne', 'disposent'],
#   ['disposent', 'tjrs'],
#   ['tjrs', 'pas'],
#   ['pas', 'de'],
#   ['de', 'toilettes.'],
#   ['toilettes.', 'https://t.co/2nC3IFHzkh']],
#  [['Reprise', 'de'],
#   ['de', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'au'],
#   ['au', 'Sud'],
#   ['Sud', 'tunisien'],
#   ['tunisien', 'https://t.co/kMu06ekNoJ']],
#  [['SONEDE:', 'Ben'],
#   ['Ben', 'Arous'],
#   ['Arous', 'et'],
#   ['et', 'Zaghouan'],
#   ['Zaghouan', 'sans'],
#   ['sans', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'https://t.co/OQlTBlP2uy']],
#  [['Tunisie:', 'Des'],
#   ['Des', 'perturbations'],
#   ['perturbations', 'et'],
#   ['et', 'coupures'],
#   ['coupures', "d'eau"],
#   ["d'eau", 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'ces'],
#   ['ces', 'zones'],
#   ['zones', 'de'],
#   ['de', 'Tunis'],
#   ['Tunis', 'https://t.co/rsD24AWWtW']],
#  [['Fourniture', 'de'],
#   ['de', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', 'par'],
#   ['par', 'affermage:'],
#   ['affermage:', 'L’Etat'],
#   ['L’Etat', 'béninois'],
#   ['béninois', 'sonde'],
#   ['sonde', 'des'],
#   ['des', 'investisseurs'],
#   ['investisseurs', 'régionaux'],
#   ['régionaux', '#Bénin'],
#   ['#Bénin', '|'],
#   ['|', 'La'],
#   ['La', 'Nouvelle'],
#   ['Nouvelle', 'Tribune'],
#   ['Tribune', 'https://t.co/PYRtvbhs6H'],
#   ['https://t.co/PYRtvbhs6H', '@lntribune']],
#  [['Gafsa:', 'des'],
#   ['des', 'citoyens'],
#   ['citoyens', 'réclament'],
#   ['réclament', 'l’accès'],
#   ['l’accès', 'à'],
#   ['à', 'l’eau'],
#   ['l’eau', 'potable'],
#   ['potable', '(Photos)'],
#   ['(Photos)', 'https://t.co/ijwLgrzj77']],
#  [['Rétablissement', 'de'],
#   ['de', 'l’approvisionnement'],
#   ['l’approvisionnement', 'en'],
#   ['en', 'eau'],
#   ['eau', 'potable'],
#   ['potable', 'dans'],
#   ['dans', 'ces'],
#   ['ces', 'régions'],
#   ['régions', 'https://t.co/9PQw3sqxa7']],
#  [['@M_Balsam', '@rania_tn'],
#   ['@rania_tn', 'نعم،'],
#   ['نعم،', 'أخطأت'],
#   ['أخطأت', 'مكان'],
#   ['مكان', 'التعليق.'],
#   ['التعليق.', 'كتبت'],
#   ['كتبت', 'تفاعلا'],
#   ['تفاعلا', 'مع'],
#   ['مع', 'كلامكم'],
#   ['كلامكم', 'انتم،'],
#   ['انتم،', 'أرى'],
#   ['أرى', 'أن'],
#   ['أن', 'بناء'],
#   ['بناء', 'مثل'],
#   ['مثل', 'هذه'],
#   ['هذه', 'المدارس'],
#   ['المدارس', 'لا'],
#   ['لا', 'فائدة'],
#   ['فائدة', 'منه'],
#   ['منه', 'خاصة'],
#   ['خاصة', 'مع'],
#   ['مع', 'الإنقطاع'],
#   ['الإنقطاع', 'المتكرر'],
#   ['المتكرر', 'للتيار'],
#   ['للتيار', 'الكهربائي'],
#   ['الكهربائي', 'و'],
#   ['و', 'الماء'],
#   ['الماء', 'الصالح'],
#   ['الصالح', 'للشراب'],
#   ['للشراب', 'حتى'],
#   ['حتى', 'في'],
#   ['في', 'العاصمة.']]]

# %% [markdown]
# ## 3. Similarity

# %% [markdown]
# ### 3.1 Edit similarity

# %%
def LD(s,t):
    s = ' ' + s      #-------------------------------------STEP:1
    t = ' ' + t      #--------------------------------------STEP:2
    d = {}
    S = len(s)
    T = len(t)
    for i in range(S):
        d[i, 0] = i #---------------------------------------STEP:3
    for j in range (T):
        d[0, j] = j #---------------------------------------STEP:4
    for j in range(1,T):
        for i in range(1,S):
            if s[i] == t[j]:
                d[i, j] = d[i-1, j-1]
            else:
                d[i, j] = min(d[i-1, j], d[i, j-1], d[i-1, j-1]) + 1
    return d[S-1, T-1]

# %%
string1="potable"
string2="perturbation"

# %%
LD(string1, string2)
# Out:
# 9

# %%
tweets[1]
# Out:
# 'Perturbations et coupures de l’approvisionnement en eau potable dans les gouvernorats de Siliana, Kasserine et Jendouba https://t.co/3Sk2V370g0'

# %%
tweets[0].split()
# Out:
# ['Les',
#  'gouvernorats',
#  'de',
#  'Siliana,',
#  'Kasserine',
#  'et',
#  'Jendouba',
#  'souffrent',
#  'de',
#  'coupures',
#  'de',
#  'l’eau',
#  'potable',
#  'https://t.co/j0bbbzzVcp']

# %%
list(map(lambda x:LD("potable",x),tweets[1].split()))
# Out:
# [11, 6, 6, 6, 16, 7, 6, 0, 6, 6, 11, 6, 7, 8, 6, 8, 21]

# %%
def compare_tweets(tw1, tw2, cl=False, lem=False):
    
    if clean:
        tw1 = clean(tw1, lem)
        tw2 = clean(tw2, lem)
    
     
    LD_matrix = []
    for w in tw1.split():
        LD_matrix_row = []
        for w2 in tw2.split():
            LD_matrix_row.append(LD(w, w2))

        LD_matrix.append(LD_matrix_row)
    
    data = pd.DataFrame(LD_matrix, columns=tw2.split(), index=tw1.split())
    
    return data

# %%
ld = compare_tweets(tweets[0],tweets[1], cl=True)

# %%
ld
# Out:
#               perturbations  coupures  approvisionnement  eau  potable  les  \
# les                      11         6                 16    3        6    0
# gouvernorats             10         8                 15   10       11   10
# siliana                  11         8                 14    6        7    6
# kasserine                10         8                 14    8        8    8
# jendouba                 10         8                 16    6        8    7
# souffrent                11         5                 12    8        7    8
# coupures                 10         0                 15    7        6    6
# eau                      11         7                 16    0        6    3
# potable                  10         6                 14    6        0    6
#
#               gouvernorats  siliana  kasserine  jendouba
# les                     10        6          8         7
# gouvernorats             0       10         10        10
# siliana                 10        0          7         7
# kasserine               10        7          0         9
# jendouba                10        7          9         0
# souffrent                8        7          7         9
# coupures                 8        8          8         8
# eau                     10        6          8         6
# potable                 11        7          8         8

# %%
# define a metric for similarity between 2 sentences
# Paper: SHORT TEXT SIMILARITY ALGORITHM BASED ON THE EDIT DISTANCE AND THESAURUS

# %% [markdown]
# ### 3.2 Cosine similarity

# %%
import math
from collections import Counter #A counter is a container that stores elements as dictionary keys, 
                                 # and their counts are stored as dictionary values.

# %%
def text_to_vector(text): 
    words = text.split() 
    return Counter(words)

# %%
text_to_vector(clean(tweets[0]))
# Out:
# Counter({'les': 1,
#          'gouvernorats': 1,
#          'siliana': 1,
#          'kasserine': 1,
#          'jendouba': 1,
#          'souffrent': 1,
#          'coupures': 1,
#          'eau': 1,
#          'potable': 1})

# %%
text_to_vector(clean(tweets[1]))
# Out:
# Counter({'perturbations': 1,
#          'coupures': 1,
#          'approvisionnement': 1,
#          'eau': 1,
#          'potable': 1,
#          'les': 1,
#          'gouvernorats': 1,
#          'siliana': 1,
#          'kasserine': 1,
#          'jendouba': 1})

# %%
def get_cosine(vec1, vec2):
    common = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in common])

    sum1 = sum([vec1[x]**2 for x in vec1.keys()]) 
    sum2 = sum([vec2[x]**2 for x in vec2.keys()]) 
    denominator = math.sqrt(sum1) * math.sqrt(sum2)
   
    if denominator:
        return float(numerator) / denominator
    else:
        return 0.0

# %%
tw1_vec = text_to_vector(clean(tweets[0]))
print("tweet 1: ",clean(tweets[0]))
tw2_vec = text_to_vector(clean(tweets[1]))
print("tweet 2: ",clean(tweets[1]))
get_cosine(tw1_vec,tw2_vec)
# Out:
# tweet 1:  les gouvernorats siliana kasserine jendouba souffrent coupures  eau potable
# tweet 2:  perturbations coupures  approvisionnement eau potable les gouvernorats siliana kasserine jendouba
# 0.8432740427115678

# %%
tw1_vec = text_to_vector(clean(tweets[0]))
print("tweet 1: ",clean(tweets[0]))
tw2_vec = text_to_vector(clean(tweets[10]))
print("tweet 2: ",clean(tweets[10]))
get_cosine(tw1_vec,tw2_vec)
# Out:
# tweet 1:  les gouvernorats siliana kasserine jendouba souffrent coupures  eau potable
# tweet 2:  vol équipements sonede prive plusieurs régions  eau potable
# 0.2357022603955158
